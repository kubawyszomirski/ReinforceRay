# %%
# imports
import pandas as pd
import numpy as np
import numpy_financial as npf
import random  
import matplotlib.pyplot as plt
import time

from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO, DQN, A2C
from stable_baselines3.common.callbacks import CallbackList, CheckpointCallback, EvalCallback
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from sb3_contrib import RecurrentPPO

from environment_fx import calculate_import_export, test1, test2, test3, evaluate1, evaluate2, basepolicy

import gymnasium as gym
from gymnasium import spaces

import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from typing import Callable

import torch
import torch as th
from torch import nn
import torch.nn as nn

import rainflow

# %%
# import and modify data

# Assuming the file is a CSV and specifying the correct path and filename
file_path = r"C:\Users\kubaw\Desktop\DELFT\THESIS\CH5"

# Use pandas to read the CSV file
AC_OUTPUT = pd.read_csv(file_path + "/AC_OUTPUT_JA")
elec_df = pd.read_csv(file_path + "/hourly_consumption_gemany.csv")
import_price = pd.read_csv(file_path + "/electricity_tariff.csv")

#elec_df = elec_df * 1000
elec_df = elec_df.drop('HourOfYear', axis=1)

elec_df['hour_of_day'] = np.arange(8760) % 24
elec_df['day_of_week'] = np.arange(8760) // 24 % 7  # 0 is Monday, 6 is Sunday

# Define rates
peak_rate = 1.45
normal_rate = 1
off_peak_rate = 0.85

# Function to determine rate based on hour and day
def determine_rate(hour, day):
    if day < 5:  # Monday to Friday
        if 16 <= hour < 21:  # 4pm to 9pm
            return peak_rate
        elif 6 <= hour < 10:  # 7am to 9am and 10am to 3pm
            return normal_rate
        else:  # Off-peak times
            return off_peak_rate
    else:  # Weekend
        if 16 <= hour < 21:  # 4pm to 9pm
            return normal_rate
        else:  # Off-peak times
            return off_peak_rate
    
# Apply the function to each row to determine the rate
elec_df['rate'] = elec_df.apply(lambda row: determine_rate(row['hour_of_day'], row['day_of_week']), axis=1)

import_price_df = import_price.drop(columns=['x'])
import_price_df = import_price_df[:-26]

train_cols = random.sample(list(import_price_df.columns), 7000)
import_price_train = import_price_df[train_cols]
test_cols = [col for col in import_price_df.columns if col not in train_cols]
import_price_test = import_price_df[test_cols]

Eff = pd.read_csv(file_path + "/Efficency_impr")
Eff = (Eff)/100 + 1

CAPEX = pd.read_csv(file_path + "/CAPEX_JA.csv")
CAPEX_JA = (CAPEX[:26])

train_cols_CAPEX = random.sample(list(CAPEX_JA.columns), 7000)
test_cols_CAPEX = [col for col in CAPEX_JA.columns if col not in train_cols_CAPEX]

CAPEX_JA_train = CAPEX_JA[train_cols_CAPEX]
CAPEX_JA_test = CAPEX_JA[test_cols_CAPEX]

train_cols_Eff = random.sample(list(Eff.columns), 7000)
test_cols_Eff = [col for col in Eff.columns if col not in train_cols_Eff]

Eff_train = Eff[train_cols_Eff]
Eff_test = Eff[test_cols_Eff]

AC_OUTPUT_arr = (np.array(AC_OUTPUT.T)).flatten()

Eff_train_arr = np.array(Eff_train.T)
Eff_test_arr = np.array(Eff_test.T)

CAPEX_JA_train_arr = np.array(CAPEX_JA_train.T)
CAPEX_JA_test_arr = np.array(CAPEX_JA_test.T)

elec_consum_arr = np.array(elec_df["Consumption"])
import_price_rate = np.array(elec_df["rate"])

import_price_train_arr = np.array(import_price_train.T)
import_price_test_arr = np.array(import_price_train.T)

file_path2 = r"C:\Users\kubaw\Desktop\DELFT\THESIS\CH6"

Battery_CAPEX = pd.read_csv(file_path2 + "/batery_CAPES.csv")
Battery_CAPEX = (Battery_CAPEX[:26])


train_cols_Battery_CAPEX = random.sample(list(Battery_CAPEX.columns), 7000)
test_cols_Battery_CAPEX = [col for col in Battery_CAPEX.columns if col not in train_cols_Battery_CAPEX]

Battery_CAPEX_train = Battery_CAPEX[train_cols_Battery_CAPEX]
Battery_CAPEX_test = Battery_CAPEX[test_cols_Battery_CAPEX]

Battery_CAPEX_train_arr = np.array(Battery_CAPEX_train.T)
Battery_CAPEX_test_arr = np.array(Battery_CAPEX_test.T)

# %%
file_path3 = r"C:\Users\kubaw\Desktop\DELFT\THESIS\CH6"
battery_degradation_arr = pd.read_csv(file_path3 + "/batery_degradation_arr.csv")
battery_degradation_arr = battery_degradation_arr.T
split_point = int(0.3 * len(battery_degradation_arr))
battery_degradation_train = battery_degradation_arr.iloc[:split_point]
battery_degradation_train_arr = battery_degradation_train.to_numpy()

battery_degradation_test = battery_degradation_arr.iloc[split_point:]
battery_degradation_test_arr = battery_degradation_test.to_numpy()

# %%
battery_degradation_test_arr[10][365*10]
# Out:
# 18.38345314558381

# %%
class TrainEnvironment(gym.Env):
    def __init__(self, AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_tariff, efficency, CAPEX, Battery_CAPEX, battery_degradation):
        
        # Price per watthour
        self.import_price_df = import_tariff
        self.import_price_at_zero = np.float32(0.00035)
        self.import_price_rate = import_price_rate
        
        # Energy Balance
        self.AC_OUTPUT = AC_OUTPUT_arr
        self.elec_df = elec_consum_arr
        self.max_export = 4000
        self.number_of_panels = 24
        
        # Degradation
        self.deg_mu = 1.055
        self.deg_std = 0.555
        
        # Efficency Development
        self.efficency_develop_df = efficency
        self.efficency_at_zero = 1.0
        
        # Costs
        self.power_at_zero = 415
        self.cost_per_Wp_df_at_zero = 0.69
        self.cost_per_Wp_df = CAPEX
        self.initial_other_costs = 150
        
        self.operational_cost = 16.8
        #self.budget_constraint = 1500
        
        self.loan_interest_rate = 1.06
        self.normal_interest_rate = 1.02
        
        self.battery_CAPEX = Battery_CAPEX
        self.battery_CAPEX_at_zero = 1
        
        self.possible_batery_sizes = 1
        
        #self.no_of_cycles = 365
        self.battery_degradation = battery_degradation
                        
        # Spaces and length
        self.action_space = spaces.MultiDiscrete([self.number_of_panels + 1, 2])
        
        self.observation_space = spaces.Box(0, 1.25, shape=(self.number_of_panels + 7 + 2,))
        self.episode_len = 25
        self.months_per_timestep = 12
        
    def _get_obs(self):
        
        return self.observation
    
    def count_cycles(self, SOC_array):
        
        cycles = list(rainflow.count_cycles(SOC_array))

        num_cycles = len(cycles)

        return cycles

    def calculate_import_export(self, AC_OUTPUT, elec_df, export_price, import_price):
        
        self.dis_max_charge = 1500
        self.dis_charge_eff = 0.95
        self.leak = self.batery_cap * 0.0001
        self.batery_cap = 5000
        self.current_battery_cap = self.batery_cap * self.battery_state
        self.leak = self.batery_cap * 0.0001
        self.min_SOC = 0.05 * self.batery_cap
        self.max_SOC = self.batery_cap 
        self.year_len = 8760
        SOC_array = []
        
        if self.battery_state == 0:
        
            AC_OUTPUT_tot = self._get_obs()[0:self.number_of_panels].sum() * self.AC_OUTPUT 

            exported = (AC_OUTPUT_tot - self.elec_df).clip(min=0, max = self.max_export)        
            export_revenue = (export_price * exported).sum()


            minimised = AC_OUTPUT_tot - exported 
            minimised_revenue = (minimised * (self.import_price_rate * import_price)).sum()
            
        else: 
            
            max_discharge = self.dis_max_charge * self.dis_charge_eff
            max_charge = self.dis_max_charge * self.dis_charge_eff
            
            
            for timestep in range(self.year_len):
                
                self.current_SOC -= self.leak 
                
                AC_OUTPUT_tot = self._get_obs()[0:self.number_of_panels].sum() * self.AC_OUTPUT
                
                pv = AC_OUTPUT_tot

                load = self.elec_df[timestep]
                elec_price = self.import_price_rate[timestep] * import_price

                if pv + self.current_SOC >= load:
                    direct_consumption = load
                    excess_pv = pv - direct_consumption
                    if excess_pv > 0:
                        potential_charge = min(excess_pv, max_charge)
                        if self.current_SOC + potential_charge > self.current_battery_cap:
                            to_grid = self.current_SOC + potential_charge - self.current_battery_cap
                            self.current_SOC = self.current_battery_cap
                        else:
                            self.current_SOC += potential_charge
                            to_grid = 0
                    else:
                        to_grid = 0
                    from_grid = 0
                else:
                    # Not enough energy from PV and battery, need grid power
                    from_pv_to_load = pv
                    needed_from_battery = load - from_pv_to_load
                    actual_discharge = min(needed_from_battery, max_discharge, self.current_SOC)
                    direct_consumption = from_pv_to_load + actual_discharge
                    self.current_SOC -= actual_discharge
                    if load > direct_consumption:
                        from_grid = load - direct_consumption
                    else:
                        from_grid = 0
                        
                SOC_array.append(current_SOC)

                # Savings from direct consumption
                minimised_revenue = direct_consumption * elec_price
                export_revenue += to_grid * export_price
            


        return export_revenue, AC_OUTPUT_tot, minimised_revenue, SOC_array    
    
    def reset(self, seed=None):
        
        """
        Reset the environment to the original state at t=1
        """
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)
        
        # Panels
        self.init_obs = np.random.uniform(0, 1, size=self.number_of_panels).astype(np.float32)
        self.init_obs = np.where(self.init_obs < 0.5, 0.0, np.random.uniform(0.85, 1.0, size=self.number_of_panels))

        # Combine all initialization into a single step for efficiency
        self.import_price_at_zero_norm = (self.import_price_at_zero - 0.00022499) / (0.0020798 - 0.00022499)
        self.FiT_at_zero_norm = (self.import_price_at_zero - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
        self.efficency_at_zero_norm = (self.efficency_at_zero - 0.999) / (1.156 - 0.999)
        self.panel_cost_and_inverter_at_zero_norm = (self.cost_per_Wp_df_at_zero - 0.1712159) / (0.8214356 - 0.1712159)
        
        self.current_budget_constraint = np.random.randint(750, 2000)
        self.next_step_budget_constraint = 0
        
        self.battery_CAPEX_at_zero_norm = (self.battery_CAPEX_at_zero - 0.03) / (4 - 0.03)
        
        # Complete observation initialization in one go
        self.observation = np.concatenate([
            self.init_obs,
            [self.import_price_at_zero_norm, self.FiT_at_zero_norm, self.efficency_at_zero_norm, 
             self.panel_cost_and_inverter_at_zero_norm, 0., 0., 0., 0., self.battery_CAPEX_at_zero_norm]
        ]).astype(np.float32)

        self.previous_observation = self.observation.copy()

        # RANDOM IMPORT PRICE
        self.random_import_price = self.import_price_df[np.random.choice(self.import_price_df.shape[0])] 

        # RANDOM EFFICENCY
        self.random_efficency_develop = self.efficency_develop_df[np.random.choice(self.efficency_develop_df.shape[0])]   
        
        # RANDOM COST PER WP
        self.random_cost_per_Wp = self.cost_per_Wp_df[np.random.choice(self.cost_per_Wp_df.shape[0])]   
        
        self.random_battery_CAPEX = self.battery_CAPEX[np.random.choice(self.battery_CAPEX.shape[0])]
        
        self.episode_len = 25  
    
        info = {}
        
        self.current_SOC = 0
        
        # RESET BALANCES
        self.fin_balance_tot = 0
        self.reward_tot = 0
        self.env_balance_tot = 0
        self.produced = 0
        self.other_costs = 0
        self.FiT = 0.0004
        self.next_FiT = 0.0004

        self.total_cash_flow = []
        self.annual_cash_flow = 0
                
        self.due_loans = [0, 0, 0, 0] 
        self.current_interest = 0
        self.step_total_interest = 1
        self.survival = np.zeros(self.number_of_panels, dtype=np.float32)
        self.resale_values = array_of_zeros = np.zeros(self.number_of_panels, dtype=np.float32)
        
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)
        
        self.two_year_ago_interest = 0
        self.first_year_interest = []
        self.second_year_interest = [0]
        self.third_year_interest = [0, 0]
        self.fourth_year_interest = [0, 0, 0]
        self.next_year_total = 0
        
        self.battery_state = 0
        
        self.survival = np.zeros(self.number_of_panels, dtype=np.float32)
    
        return self.observation, info
    
    def calculate_resale(self, initial_panel_cost, indices):
        
        self.resale_values[indices] = initial_panel_cost
        
        self.resale_values = self.resale_values * 0.85
        
        for count, i in enumerate(self.broke):
            if i == 1:
                self.resale_values[count] = 0
        
        resale_step = self.resale_values[indices].sum()
        
        return resale_step
    
    def calculate_panel_inv_cost(self, cost_per_Wp):
        
        PW_ep = self.efficency_develop * self.power_at_zero
        
        panel_cost_and_inverter = PW_ep * cost_per_Wp
        
        return panel_cost_and_inverter
        
    def calculate_penalty(self, current_step, annual_expense):
              
        year = 25 - current_step
        
        if year > 0:
            self.current_budget_constraint = self.next_step_budget_constraint    
            
        
        self.current_interest = self.next_year_total
        annual_expense = (-annual_expense)
        value = 0 
        loan = 0
        annual_interest = 0

        if annual_expense > self.current_budget_constraint:
            loan = (self.current_budget_constraint - annual_expense)
            value = annual_expense / self.current_budget_constraint
            periods = 2 if value < 2 else 3 if value < 3 else 4

            annual_interest = loan / periods
            interest_multiplier = 1

            for i in range(4):
                if i < periods:
                    self.due_loans[i] = annual_interest * interest_multiplier
                    interest_multiplier *= self.loan_interest_rate
                else:
                    self.due_loans[i] = 0
        else:
             self.due_loans = [0, 0, 0, 0]
    
        self.first_year_interest.append(self.due_loans[0])
        self.second_year_interest.append(self.due_loans[1])
        self.third_year_interest.append(self.due_loans[2])
        self.fourth_year_interest.append(self.due_loans[3])
    
    
        self.next_year_total = self.first_year_interest[year] + self.second_year_interest[year] + self.third_year_interest[year] + self.fourth_year_interest[year]
        
        self.next_step_budget_constraint = np.random.randint(750, 2000) * self.step_total_interest
        current_budget_observation = (self.next_step_budget_constraint - 750 * self.step_total_interest) / (2000 * self.step_total_interest - 750 * self.step_total_interest) 
        self.observation[self.number_of_panels + 6] = current_budget_observation
                
        return self.current_interest, self.due_loans, self.next_year_total
    
    def determine_battery_degradation(self, action_battery, no_cycles):
        
        if action_battery == 1:
            battery_state = 1
            random_column_index = np.random.randint(self.battery_degradation.shape[1])
            degradation_path = self.battery_degradation[:, random_column_index]
            year_of_install = abs(self.episode_len - 25)
            
        if self.observation[31] > 0:
            year_since_install = abs(year_of_install - 25)
            current_degradation = degradation_path[year_since_install * no_cycles]
            battery_state -= year_since_install/100
        
        return battery_state

    def calculate_total_CAPEX(self, action_step, panel_cost_and_inverter):
        """
        Calculate CAPEX each step in a vectorized manner.
        """
        BOS = panel_cost_and_inverter * 0.55
        number_installed = int(np.sum(action_step))

        # Calculate costs from module and inverter
        panel_cost_and_inverter_step = panel_cost_and_inverter * number_installed

        # Calculate other installation costs
        if number_installed == 0:
            other_costs = 0
        elif number_installed == 1:
            other_costs = self.initial_other_costs * self.step_total_interest
        else:
            discounts = 0.9 ** np.arange(number_installed)
            other_costs = (self.initial_other_costs * self.step_total_interest * discounts).sum()

        # Calculate BOS costs using vector operations
        is_new_installation = (self.previous_observation[:number_installed] == 0) & (action_step[:number_installed] == 1)
        is_replacement = (self.previous_observation[:number_installed] > 0) & (action_step[:number_installed] == 1)
        BOS_cost = np.sum(BOS * is_new_installation) + np.sum((BOS / 2) * is_replacement)

        # Sum total CAPEX
        total_CAPEX = panel_cost_and_inverter_step + BOS_cost + other_costs

        return total_CAPEX, panel_cost_and_inverter
        
    def failure(self, actions):
        
        beta = 3  # Shape parameter
        phi = 30  # Scale parameter  

        # Determine which panels are active based on the actions and previous observations.
        if self.episode_len == 24:
            active_panels = (self.observation[:self.number_of_panels] > 0.85)
        else:
            active_panels = (self.observation[:self.number_of_panels] == self.efficency_develop)

        # Calculate lifespan for all active panels at once
        lifespans = np.random.weibull(beta, self.number_of_panels) * phi
        lifespans = np.where(active_panels, lifespans, 0)  # Apply lifespan only to active panels

        # Adjust survival times based on episode length
        self.survival[:self.number_of_panels] = np.where(
            active_panels,
            np.abs(lifespans.astype(int)) + np.abs(self.episode_len - 25),
            self.survival[:self.number_of_panels]
        )

        return self.survival

    def calculate_FiT(self, episodes, import_price):
            
        self.FiT = import_price
            
        if episodes == 25:
            self.FiT = self.FiT
            
        elif episodes == 24 or episodes == 23:
            self.FiT = self.FiT * 0.64
            
        elif episodes == 22:
            self.FiT = self.FiT * 0.46
            
        elif episodes == 21:
            self.FiT = self.FiT * 0.55
            
        elif episodes < 20:
            self.FiT = self.FiT * 0.33
            
        elif episodes == 20:
            self.FiT = self.FiT * 0.37
            
        return self.FiT
                        
    def calculate_battery_CAPEX(self, action_battery):
        
        five_kw_PRICE = 3000

        installation = 1000 * self.step_total_interest
        
        this_battery_CAPEX = five_kw_PRICE * self.step_battery_CAPEX
        
        battery_bos = this_battery_CAPEX * 0.5
        
        if self.previous_observation[19] == 0:
            battery_bos = this_battery_CAPEX * 0.5
        else:
            battery_bos = 0
        
        total_batery_cost = (this_battery_CAPEX +  battery_bos + installation) * action_battery
        
        return total_batery_cost
        
    def step(self, action):
        
        """
        defines actions, reward etc.
        """
        
        # RESET THE ANNUAL BALANCES
        self.total_CAPEX = 0
        self.pv_costs = 0
        self.fin_balance = 0
        self.number_installed = 0
        current_penalty = 0
        self.other_costs = 0
        battery_costs = 0
        no_cycles = 0
        next_step_penalty = 0
        self.step_total_interest = self.step_total_interest * self.normal_interest_rate
        current_operational_costs = self.operational_cost * self.step_total_interest
        
        #***
        self.step_battery_CAPEX = self.random_battery_CAPEX[abs(self.episode_len - 25)]
        
        self.cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
        self.import_price = self.random_import_price[abs(self.episode_len - 25)]
        self.efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
           
        self.panel_cost_and_inverter = self.calculate_panel_inv_cost(self.cost_per_Wp)
        FiT = self.calculate_FiT(self.episode_len, self.import_price)
        
        reward = 0   
        actions_step = np.random.rand(12)
        
        #  ***
        action_battery = action[1]
        action = action[0]
        
        # Find indices of the lowest 'action' values in previous_observation
        indices = np.argsort(self.previous_observation[:self.number_of_panels])[:action]

        # Replace these indices in the observation with efficiency_develop
        self.observation[:self.number_of_panels][indices] = self.efficency_develop

        # Copy over the other values from previous_observation to observation
        mask = np.ones(len(self.previous_observation[:self.number_of_panels]), dtype=bool)
        mask[indices] = False
        self.observation[:self.number_of_panels][mask] = self.previous_observation[:self.number_of_panels][mask]

        replaced_panels = np.zeros(len(self.previous_observation[:self.number_of_panels]), dtype=int)
        replaced_panels[indices] = 1

        instaltion = (self.observation[:self.number_of_panels] > 0).astype(int)
        self.pv_costs -= instaltion.sum() * current_operational_costs

        actions_step = np.array(replaced_panels)
        
        if action_battery == 1:           
            self.observation[31] = 1.
            self.battery_state = 1
            
        if action > 0:
            step_CAPEX, panel_cost_and_inverter = self.calculate_total_CAPEX(actions_step, self.panel_cost_and_inverter)
            self.pv_costs -= step_CAPEX
            
        else:
            panel_cost_and_inverter = 0
            
        battery_costs = self.calculate_battery_CAPEX(action_battery)
        
        self.pv_costs -= battery_costs

        
        next_observation = self._get_obs()

        # Calculate the Reslae value
        resale = self.calculate_resale(panel_cost_and_inverter, indices)
        
        self.pv_costs += resale
 
        
        # CALCULATE THE BUDGET INTEREST
        current_penalty, due_loans, next_step_penalty = self.calculate_penalty(self.episode_len, self.pv_costs)

        
        # CALCULATE THE ENERGY YIELD
        exported_revenue, AC_OUTPUT_tot, minimised_revenue, SOC_array = self.calculate_import_export(self.AC_OUTPUT, 
                                                                          self.elec_df, FiT, self.import_price)        
        
        no_cycles = self.count_cycles(SOC_array)
        pv_costs_observation = - self.pv_costs / 9000
        self.observation[self.number_of_panels + 4] = pv_costs_observation
        
        next_step_penalty_observation = - next_step_penalty / 7000
        self.observation[self.number_of_panels + 5] = next_step_penalty_observation
        
        
        # CALCULATE STEP BALANCES
        self.fin_balance += self.pv_costs
        self.fin_balance += current_penalty
        self.fin_balance += float(exported_revenue + minimised_revenue)
        
        # CALCULATE TOTAL BALANCES
        self.fin_balance_tot += self.fin_balance                
        
        # SUBSTRACT 1 FOR TIMESTEP
        self.episode_len -= 1
        done = self.episode_len <= 0
        
        #reward = self.fin_balance_tot / 1000 if done else 0
        reward = self.fin_balance / 1000
        
        # FAILURE
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)
        survival = self.failure(actions_step)
        
        for c, p in enumerate(survival):
            
            if c < self.number_of_panels:

                if p - 1 <= abs(self.episode_len - 24):
                    self.broke[c] = 1
                    self.observation[c] = 0
        
        # DEGRADATION RATE
        # Applying degradation only to panels that are operational (above 0.1 efficiency)
        active_panels = self.observation[:self.number_of_panels] > 0.1
        degradations = np.random.normal(self.deg_mu, self.deg_std, size=self.number_of_panels) / 100
        self.observation[:self.number_of_panels][active_panels] -= degradations[active_panels]
        
        # BATERY DEGRADATION
        self.battery_state = determine_battery_degradation(action_battery, no_cycles)
        
        self.observation[31] = self.battery_state
        
        if not done: 
        
            self.next_cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
            self.next_import_price = self.random_import_price[abs(self.episode_len - 25)]
            self.next_efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
            next_FIT = self.calculate_FiT(self.episode_len, self.next_import_price)
        
            price_observation = (self.next_import_price - 0.00022499) / (0.0020798 - 0.00022499)
            self.observation[self.number_of_panels] = price_observation

            FiT_observation = (next_FIT - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
            self.observation[self.number_of_panels + 1] = FiT_observation

            eff_observation = (self.next_efficency_develop - 0.999) / (1.156 - 0.999)
            self.observation[self.number_of_panels + 2] = eff_observation

            cost_per_Wp_observation = (self.next_cost_per_Wp - 0.1712159) / (0.8214356 - 0.1712159) 
            self.observation[self.number_of_panels + 3] = cost_per_Wp_observation
            
            step_battery_CAPEX_obs = (self.step_battery_CAPEX - 0.03) / (4 - 0.03)
            self.observation[32] = step_battery_CAPEX_obs
        
        info = {"step financial balance (eur):": battery_costs,
               "total financial balance: (eur)": minimised_revenue,
               "internal rate of return": 0,
               "current_interest": resale,
                "net present value": 0}
         
        
        self.previous_observation = self.observation.copy()
        
        return self.observation, reward, done, False, info

# %%
class TestEnvironment(gym.Env):
    def __init__(self, AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_tariff, efficency, CAPEX, Battery_CAPEX,battery_degradation):
        
        # Price per watthour
        self.import_price_df = import_tariff
        self.import_price_at_zero = np.float32(0.00035)
        self.import_price_rate = import_price_rate
        
        # Energy Balance
        self.AC_OUTPUT = AC_OUTPUT_arr
        self.elec_df = elec_consum_arr
        self.max_export = 4000
        self.number_of_panels = 24
        
        # Degradation
        self.deg_mu = 1.055
        self.deg_std = 0.555
        
        # Efficency Development
        self.efficency_develop_df = efficency
        self.efficency_at_zero = 1.0
        
        # Costs
        self.power_at_zero = 415
        self.cost_per_Wp_df_at_zero = 0.69
        self.cost_per_Wp_df = CAPEX
        self.initial_other_costs = 150
        
        self.operational_cost = 16.8
        #self.budget_constraint = 1500
        
        self.no_of_cycles = 365
        self.battery_degradation = battery_degradation
        self.loan_interest_rate = 1.06
        self.normal_interest_rate = 1.02
        
        self.battery_CAPEX = Battery_CAPEX
        self.battery_CAPEX_at_zero = 1
            
        # Spaces and length
        self.action_space = spaces.MultiDiscrete([self.number_of_panels + 1, 2])
        self.observation_space = spaces.Box(0, 1.25, shape=(self.number_of_panels + 7 + 2,))
        self.episode_len = 25
        self.months_per_timestep = 12
        
    def _get_obs(self):
        
        return self.observation
    
    def count_cycles(self, SOC_array):
        
        cycles = list(rainflow.count_cycles(SOC_array))

        num_cycles = len(cycles)

        return cycles

    def calculate_import_export(self, AC_OUTPUT, elec_df, export_price, import_price):
        
        self.dis_max_charge = 1500
        self.dis_charge_eff = 0.95
        self.leak = self.batery_cap * 0.0001
        self.batery_cap = 5000
        self.current_battery_cap = self.batery_cap * self.battery_state
        self.leak = self.batery_cap * 0.0001
        self.min_SOC = 0.05 * self.batery_cap
        self.max_SOC = self.batery_cap 
        self.year_len = 8760
        SOC_array = []
        
        if self.battery_state == 0:
        
            AC_OUTPUT_tot = self._get_obs()[0:self.number_of_panels].sum() * self.AC_OUTPUT 

            exported = (AC_OUTPUT_tot - self.elec_df).clip(min=0, max = self.max_export)        
            export_revenue = (export_price * exported).sum()


            minimised = AC_OUTPUT_tot - exported 
            minimised_revenue = (minimised * (self.import_price_rate * import_price)).sum()
            
        else: 
            
            max_discharge = self.dis_max_charge * self.dis_charge_eff
            max_charge = self.dis_max_charge * self.dis_charge_eff
            
            
            for timestep in range(self.year_len):
                
                self.current_SOC -= self.leak 
                
                AC_OUTPUT_tot = self._get_obs()[0:self.number_of_panels].sum() * self.AC_OUTPUT
                
                pv = AC_OUTPUT_tot

                load = self.elec_df[timestep]
                elec_price = self.import_price_rate[timestep] * import_price

                if pv + self.current_SOC >= load:
                    direct_consumption = load
                    excess_pv = pv - direct_consumption
                    if excess_pv > 0:
                        potential_charge = min(excess_pv, max_charge)
                        if self.current_SOC + potential_charge > self.current_battery_cap:
                            to_grid = self.current_SOC + potential_charge - self.current_battery_cap
                            self.current_SOC = self.current_battery_cap
                        else:
                            self.current_SOC += potential_charge
                            to_grid = 0
                    else:
                        to_grid = 0
                    from_grid = 0
                else:
                    # Not enough energy from PV and battery, need grid power
                    from_pv_to_load = pv
                    needed_from_battery = load - from_pv_to_load
                    actual_discharge = min(needed_from_battery, max_discharge, self.current_SOC)
                    direct_consumption = from_pv_to_load + actual_discharge
                    self.current_SOC -= actual_discharge
                    if load > direct_consumption:
                        from_grid = load - direct_consumption
                    else:
                        from_grid = 0
                        
                SOC_array.append(current_SOC)

                # Savings from direct consumption
                minimised_revenue = direct_consumption * elec_price
                export_revenue += to_grid * export_price
            


        return export_revenue, AC_OUTPUT_tot, minimised_revenue, SOC_array    
    
    def reset(self, seed=None):
        
        """
        Reset the environment to the original state at t=1
        """
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)
            
        # Panels
        self.init_obs = np.random.uniform(0, 1, size=self.number_of_panels).astype(np.float32)
        self.init_obs = np.where(self.init_obs < 0.5, 0.0, np.random.uniform(0.85, 1.0, size=self.number_of_panels))

        # Combine all initialization into a single step for efficiency
        self.import_price_at_zero_norm = (self.import_price_at_zero - 0.00022499) / (0.0020798 - 0.00022499)
        self.FiT_at_zero_norm = (self.import_price_at_zero - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
        self.efficency_at_zero_norm = (self.efficency_at_zero - 0.999) / (1.156 - 0.999)
        self.panel_cost_and_inverter_at_zero_norm = (self.cost_per_Wp_df_at_zero - 0.1712159) / (0.8214356 - 0.1712159)
        
        self.current_budget_constraint = np.random.randint(750, 2000)
        self.next_step_budget_constraint = 0
        
        
        self.battery_CAPEX_at_zero_norm = (self.battery_CAPEX_at_zero - 0.03) / (4 - 0.03)
        
        # Complete observation initialization in one go
        self.observation = np.concatenate([
            self.init_obs,
            [self.import_price_at_zero_norm, self.FiT_at_zero_norm, self.efficency_at_zero_norm, 
             self.panel_cost_and_inverter_at_zero_norm, 0., 0., 0., 0., self.battery_CAPEX_at_zero_norm]
        ]).astype(np.float32)

        self.previous_observation = self.observation.copy()

        # RANDOM IMPORT PRICE
        self.random_import_price = self.import_price_df[np.random.choice(self.import_price_df.shape[0])] 

        # RANDOM EFFICENCY
        self.random_efficency_develop = self.efficency_develop_df[np.random.choice(self.efficency_develop_df.shape[0])]   
        
        # RANDOM COST PER WP
        self.random_cost_per_Wp = self.cost_per_Wp_df[np.random.choice(self.cost_per_Wp_df.shape[0])]   
        
        self.random_battery_CAPEX = self.battery_CAPEX[np.random.choice(self.battery_CAPEX.shape[0])]
        
        self.episode_len = 25  
    
        info = {}
        
        self.current_SOC = 0
        
        # RESET BALANCES
        self.fin_balance_tot = 0
        self.reward_tot = 0
        self.env_balance_tot = 0
        self.produced = 0
        self.other_costs = 0
        self.FiT = 0.0004
        self.next_FiT = 0.0004
        self.resale_values = array_of_zeros = np.zeros(self.number_of_panels, dtype=np.float32)
        
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)
        self.total_cash_flow = []
        self.annual_cash_flow = 0
                
        self.due_loans = [0, 0, 0, 0] 
        self.current_interest = 0
        self.step_total_interest = 1
        
        self.two_year_ago_interest = 0
        self.first_year_interest = []
        self.second_year_interest = [0]
        self.third_year_interest = [0, 0]
        self.fourth_year_interest = [0, 0, 0]
        self.next_year_total = 0
        self.battery_state = 0

        self.survival = np.zeros(self.number_of_panels, dtype=np.float32)
    
        return self.observation, info
    
    def calculate_resale(self, initial_panel_cost, indices):
        
        self.resale_values[indices] = initial_panel_cost
        
        self.resale_values = self.resale_values * 0.85
        
        for count, i in enumerate(self.broke):
            if i == 1:
                self.resale_values[count] = 0
        
        resale_step = self.resale_values[indices].sum()
        
        return resale_step
    
    def calculate_panel_inv_cost(self, cost_per_Wp):
        
        PW_ep = self.efficency_develop * self.power_at_zero
        
        panel_cost_and_inverter = PW_ep * cost_per_Wp
        
        return panel_cost_and_inverter
    
    def calculate_irr_and_npv(self, pv_cost, minimised_revenue, export_revenue, penalty):
                
        """
        Calculates total cash flow of the project needed for the internal rate of return
        """ 
        self.expences = 0
        self.annual_cash_flow = 0
        initial_cost = 0
        
        self.expences = pv_cost
        self.annual_cash_flow = self.expences + export_revenue + minimised_revenue + penalty
        initial_cost_q, x = self.calculate_total_CAPEX(self.init_obs, self.panel_cost_and_inverter)
        initial_cost = - initial_cost_q
        
        if self.episode_len == 24:
            self.total_cash_flow.append(initial_cost + self.annual_cash_flow) 
        else:
            self.total_cash_flow.append(self.annual_cash_flow) 
        
        return self.total_cash_flow
        
    def calculate_penalty(self, current_step, annual_expense):
              
        year = 25 - current_step
        
        if year > 0:
            self.current_budget_constraint = self.next_step_budget_constraint    
            
        
        self.current_interest = self.next_year_total
        annual_expense = (-annual_expense)
        value = 0 
        loan = 0
        annual_interest = 0

        if annual_expense > self.current_budget_constraint:
            loan = (self.current_budget_constraint - annual_expense)
            value = annual_expense / self.current_budget_constraint
            periods = 2 if value < 2 else 3 if value < 3 else 4

            annual_interest = loan / periods
            interest_multiplier = 1

            for i in range(4):
                if i < periods:
                    self.due_loans[i] = annual_interest * interest_multiplier
                    interest_multiplier *= self.loan_interest_rate
                else:
                    self.due_loans[i] = 0
        else:
             self.due_loans = [0, 0, 0, 0]
    
        self.first_year_interest.append(self.due_loans[0])
        self.second_year_interest.append(self.due_loans[1])
        self.third_year_interest.append(self.due_loans[2])
        self.fourth_year_interest.append(self.due_loans[3])
    
    
        self.next_year_total = self.first_year_interest[year] + self.second_year_interest[year] + self.third_year_interest[year] + self.fourth_year_interest[year]
        
        self.next_step_budget_constraint = np.random.randint(750, 2000) * self.step_total_interest
        current_budget_observation = (self.next_step_budget_constraint - 750 * self.step_total_interest) / (2000 * self.step_total_interest - 750 * self.step_total_interest) 
        self.observation[self.number_of_panels + 6] = current_budget_observation
                
        return self.current_interest, self.due_loans, self.next_year_total
    
    def determine_battery_degradation(self, action_battery, no_cycles):
        
        if action_battery == 1:
            battery_state = 1
            random_column_index = np.random.randint(self.battery_degradation.shape[1])
            degradation_path = self.battery_degradation[:, random_column_index]
            year_of_install = abs(self.episode_len - 25)
            
        if self.observation[31] > 0:
            year_since_install = abs(year_of_install - 25)
            current_degradation = degradation_path[year_since_install * no_cycles]
            battery_state -= year_since_install/100
        
        return battery_state
        
    def calculate_total_CAPEX(self, action_step, panel_cost_and_inverter):
        """
        Calculate CAPEX each step in a vectorized manner.
        """
        BOS = panel_cost_and_inverter * 0.55
        number_installed = int(np.sum(action_step))

        # Calculate costs from module and inverter
        panel_cost_and_inverter_step = panel_cost_and_inverter * number_installed

        # Calculate other installation costs
        if number_installed == 0:
            other_costs = 0
        elif number_installed == 1:
            other_costs = self.initial_other_costs * self.step_total_interest
        else:
            discounts = 0.9 ** np.arange(number_installed)
            other_costs = (self.initial_other_costs * self.step_total_interest * discounts).sum()

        # Calculate BOS costs using vector operations
        is_new_installation = (self.previous_observation[:number_installed] == 0) & (action_step[:number_installed] == 1)
        is_replacement = (self.previous_observation[:number_installed] > 0) & (action_step[:number_installed] == 1)
        BOS_cost = np.sum(BOS * is_new_installation) + np.sum((BOS / 2) * is_replacement)

        # Sum total CAPEX
        total_CAPEX = panel_cost_and_inverter_step + BOS_cost + other_costs

        return total_CAPEX, panel_cost_and_inverter
        
    def failure(self, actions):
        
        beta = 3  # Shape parameter
        phi = 30  # Scale parameter  

        # Determine which panels are active based on the actions and previous observations.
        if self.episode_len == 24:
            active_panels = (self.observation[:self.number_of_panels] > 0.85)
        else:
            active_panels = (self.observation[:self.number_of_panels] == self.efficency_develop)

        # Calculate lifespan for all active panels at once
        lifespans = np.random.weibull(beta, self.number_of_panels) * phi
        lifespans = np.where(active_panels, lifespans, 0)  # Apply lifespan only to active panels

        # Adjust survival times based on episode length
        self.survival[:self.number_of_panels] = np.where(
            active_panels,
            np.abs(lifespans.astype(int)) + np.abs(self.episode_len - 25),
            self.survival[:self.number_of_panels]
        )

        return self.survival

    def calculate_FiT(self, episodes, import_price):
            
        self.FiT = import_price
            
        if episodes == 25:
            self.FiT = self.FiT
            
        elif episodes == 24 or episodes == 23:
            self.FiT = self.FiT * 0.64
            
        elif episodes == 22:
            self.FiT = self.FiT * 0.46
            
        elif episodes == 21:
            self.FiT = self.FiT * 0.55
            
        elif episodes < 20:
            self.FiT = self.FiT * 0.33
            
        elif episodes == 20:
            self.FiT = self.FiT * 0.37
            
        return self.FiT
    
    def calculate_battery_CAPEX(self, action_battery):
        
        five_kw_PRICE = 3000

        installation = 1000 * self.step_total_interest
        
        this_battery_CAPEX = five_kw_PRICE * self.step_battery_CAPEX
        
        battery_bos = this_battery_CAPEX * 0.5
        
        if self.previous_observation[19] == 0:
            battery_bos = this_battery_CAPEX * 0.5
        else:
            battery_bos = 0
        
        total_batery_cost = (this_battery_CAPEX +  battery_bos + installation) * action_battery
        
        return total_batery_cost
                  
    def step(self, action):
        
        """
        defines actions, reward etc.
        """
        
        # RESET THE ANNUAL BALANCES
        self.total_CAPEX = 0
        self.pv_costs = 0
        self.fin_balance = 0
        self.number_installed = 0
        irr_fin = 0
        npv_fin = 0
        battery_costs = 0
        current_penalty = 0
        self.other_costs = 0
        next_step_penalty = 0
        self.step_total_interest = self.step_total_interest * self.normal_interest_rate
        current_operational_costs = self.operational_cost * self.step_total_interest
        self.step_battery_CAPEX = self.random_battery_CAPEX[abs(self.episode_len - 25)]

        
        self.cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
        self.import_price = self.random_import_price[abs(self.episode_len - 25)]
        self.efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
           
        self.panel_cost_and_inverter = self.calculate_panel_inv_cost(self.cost_per_Wp)
        FiT = self.calculate_FiT(self.episode_len, self.import_price)
        
        reward = 0   
        actions_step = np.random.rand(self.number_of_panels + 1)
        
        
        action_battery = action[1]
        action = action[0]
        
        # Find indices of the lowest 'action' values in previous_observation
        indices = np.argsort(self.previous_observation[:self.number_of_panels])[:action]

        # Replace these indices in the observation with efficiency_develop
        self.observation[:self.number_of_panels][indices] = self.efficency_develop

        # Copy over the other values from previous_observation to observation
        mask = np.ones(len(self.previous_observation[:self.number_of_panels]), dtype=bool)
        mask[indices] = False
        self.observation[:self.number_of_panels][mask] = self.previous_observation[:self.number_of_panels][mask]

        replaced_panels = np.zeros(len(self.previous_observation[:self.number_of_panels]), dtype=int)
        replaced_panels[indices] = 1

        instaltion = (self.observation[:self.number_of_panels] > 0).astype(int)
        self.pv_costs -= instaltion.sum() * current_operational_costs

        actions_step = np.array(replaced_panels)
        
        if action_battery == 1:           
            self.observation[31] = 1.
            self.battery_state = 1
            
        if action > 0:
            step_CAPEX, panel_cost_and_inverter = self.calculate_total_CAPEX(actions_step, self.panel_cost_and_inverter)
            self.pv_costs -= step_CAPEX
            
        else:
            panel_cost_and_inverter = 0
            
        battery_costs = self.calculate_battery_CAPEX(action_battery)
        
        self.pv_costs -= battery_costs
        next_observation = self._get_obs()

        # Calculate the Reslae value
        resale = self.calculate_resale(panel_cost_and_inverter, indices) #  ***
        
        self.pv_costs += resale

        
        # CALCULATE THE BUDGET INTEREST
        current_penalty, due_loans, next_step_penalty = self.calculate_penalty(self.episode_len, self.pv_costs)
        
        
        # CALCULATE THE ENERGY YIELD
        exported_revenue, AC_OUTPUT_tot, minimised_revenue, SOC_array = self.calculate_import_export(self.AC_OUTPUT, 
                                                                          self.elec_df, FiT, self.import_price)        
        
        no_cycles = self.count_cycles(SOC_array)
        
        pv_costs_observation = - self.pv_costs / 9000
        self.observation[self.number_of_panels + 4] = pv_costs_observation
        
        next_step_penalty_observation = - next_step_penalty / 7000
        self.observation[self.number_of_panels + 5] = next_step_penalty_observation
        
        
        # CALCULATE STEP BALANCES
        self.fin_balance += self.pv_costs
        self.fin_balance += current_penalty
        self.fin_balance += float(exported_revenue + minimised_revenue)
        
        # CALCULATE TOTAL BALANCES
        self.fin_balance_tot += self.fin_balance                
        
        # SUBSTRACT 1 FOR TIMESTEP
        self.episode_len -= 1
        done = self.episode_len <= 0
        
        # CALCULATE IRR, NPV AND CARBON INTENSITY
        total_cash_flow = self.calculate_irr_and_npv(self.pv_costs, exported_revenue, minimised_revenue, current_penalty)
        irr = npf.irr(total_cash_flow) * 100
        npv = npf.npv(0.04 ,total_cash_flow)
            
        # RETURNS AND CALCULATE REWARD
        if self.episode_len == 0:
            irr_fin = irr
            npv_fin = npv

        reward = self.fin_balance_tot / 1000 if done else 0
        
        # FAILURE
         
        survival = self.failure(actions_step)
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)

        for c, p in enumerate(survival):
            
            if c < self.number_of_panels:

                if p - 1 <= abs(self.episode_len - 24):
                    self.broke[c] = 1

                    self.observation[c] = 0
        
        # DEGRADATION RATE
        # Applying degradation only to panels that are operational (above 0.1 efficiency)
        active_panels = self.observation[:self.number_of_panels] > 0.1
        degradations = np.random.normal(self.deg_mu, self.deg_std, size=self.number_of_panels) / 100
        self.observation[:self.number_of_panels][active_panels] -= degradations[active_panels]
        
        # BATERY DEGRADATION
        self.battery_state = determine_battery_degradation(action_battery, no_cycles)
        
        self.observation[31] = self.battery_state


        
        if not done: 
        
            self.next_cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
            self.next_import_price = self.random_import_price[abs(self.episode_len - 25)]
            self.next_efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
            next_FIT = self.calculate_FiT(self.episode_len, self.next_import_price)
        
            price_observation = (self.next_import_price - 0.00022499) / (0.0020798 - 0.00022499)
            self.observation[self.number_of_panels] = price_observation

            FiT_observation = (next_FIT - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
            self.observation[self.number_of_panels + 1] = FiT_observation

            eff_observation = (self.next_efficency_develop - 0.999) / (1.156 - 0.999)
            self.observation[self.number_of_panels + 2] = eff_observation

            cost_per_Wp_observation = (self.next_cost_per_Wp - 0.1712159) / (0.8214356 - 0.1712159) 
            self.observation[self.number_of_panels + 3] = cost_per_Wp_observation
            
            step_battery_CAPEX_obs = (self.step_battery_CAPEX - 0.03) / (4 - 0.03)
            self.observation[32] = step_battery_CAPEX_obs
        
        info = {"step financial balance (eur):": self.fin_balance,
               "total financial balance: (eur)": self.fin_balance_tot,
               "internal rate of return": irr_fin,
               "current_interest": current_penalty,
                "net present value": npv_fin}
         
        
        self.previous_observation = self.observation.copy()
        
        return self.observation, reward, done, False, info

# %%
env = TrainEnvironment(AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_price_train_arr, Eff_train_arr, CAPEX_JA_train_arr, Battery_CAPEX_train_arr, battery_degradation_train_arr)
env_test = TestEnvironment(AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_price_test_arr, Eff_test_arr, CAPEX_JA_test_arr, Battery_CAPEX_test_arr, battery_degradation_test_arr)

# %%
#check_env(env)

# %%
def test3(episodes, environment):    
    for episode in range(episodes):
        done = False
        obs = environment.reset()
        step = 0
        print(obs, "\n")
        while not done:
            step += 1
            random_action = environment.action_space.sample()
            obs, reward, done, trun, info = environment.step(random_action)
            
            
            # Extracting the 2nd and 3rd key-value pairs
            keys = list(info.keys())
            values = list(info.values())

            # Getting the 2nd key-value pair
            zeroth_key = keys[0]
            zeroth_value = values[0]

            # Getting the 3rd key-value pair

            sixth_key = keys[3]
            sixth_value = values[3]
            
            print("STEP:", step)
            print("ACT","\n",  random_action)
            print("OBS","\n",  obs)
            print(zeroth_key, zeroth_value, sixth_key, sixth_value)
            print("\n")

# %%
#test3(1, env)

# %%
#test1(1000, env)

# %%
def make_env(rank: int, seed: int = 0) -> Callable:
    def _init() -> gym.Env:
        random.seed(seed + rank)
        np.random.seed(seed + rank) 
        env = TrainEnvironment(AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_price_train_arr, Eff_train_arr, CAPEX_JA_train_arr, Battery_CAPEX_train_arr)
        env.reset(seed=seed + rank)
        return env

    return _init
# Number of environments to run in parallel
num_cpu = 16
env = SubprocVecEnv([make_env(i) for i in range(num_cpu)])

# %%
import math
def logarithmic_schedule(initial_value, final_value=0.00001):
    """
    Returns a function that computes a logarithmically decreasing value from initial_value to final_value.
    """
    def func(progress_remaining):
        # Avoid taking log of zero by setting a lower limit close to zero
        epsilon = 0.0001
        progress = max(epsilon, 1 - progress_remaining)
        # Calculate the decay factor using a logarithmic scale
        return final_value + (initial_value - final_value) * math.log(1/progress)
    return func


learning_rate = logarithmic_schedule(0.0001)

# %%
def linear_schedule(initial_value, final_value=0.00001):
    """
    Returns a function that computes a linearly decreasing value from initial_value to final_value.
    """
    def func(progress_remaining):
        # Calculate the decrease based on the remaining progress
        return final_value + (initial_value - final_value) * progress_remaining
    return func

# Define the learning rate using the linear schedule
learning_rate = linear_schedule(0.0003)

# %%
log_path = "./logs/"
eval_callback = EvalCallback(env_test, best_model_save_path = "C:/Users/kubaw/Desktop/DELFT/THESIS/CODE/TEST_MODELS/baterytrina24_high/",
                             log_path = log_path, n_eval_episodes = 750, eval_freq=10000,
                             deterministic=True, render=False)


policy_kwargs = dict(net_arch=dict(pi=[1024, 1024], vf=[1024, 1024]))

# %%
model = PPO("MlpPolicy", env, learning_rate = learning_rate, batch_size = 1024, n_epochs = 24,  policy_kwargs = policy_kwargs, gamma = 0.99,  verbose=1, tensorboard_log = "C:/Users/kubaw/Desktop/DELFT/THESIS\CODE/TEST_MODELS/LOGS/logs")
TIMESTEPS = 5000000
model.learn(total_timesteps = TIMESTEPS, callback=eval_callback)
# Out:
# Using cpu device
# Logging to C:/Users/kubaw/Desktop/DELFT/THESIS\CODE/TEST_MODELS/LOGS/logs\PPO_395
# C:\Users\kubaw\miniforge3\envs\pytorch-env\lib\site-packages\stable_baselines3\common\callbacks.py:414: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x000002A096B3F460> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x000002A0A8C91ED0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ------------------------------
# | time/              |       |
# |    fps             | 3612  |
# |    iterations      | 1     |
# |    time_elapsed    | 9     |
# |    total_timesteps | 32768 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 2           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.018437067 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.0011      |
# |    learning_rate        | 0.000298    |
# |    loss                 | 58.6        |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0313     |
# |    value_loss           | 236         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 3           |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.023075376 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.000296    |
# |    loss                 | 62.9        |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.0408     |
# |    value_loss           | 135         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 679         |
# |    iterations           | 4           |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.020100195 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.000294    |
# |    loss                 | 56.6        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.0413     |
# |    value_loss           | 114         |
# -----------------------------------------
# C:\Users\kubaw\miniforge3\envs\pytorch-env\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=160000, episode_reward=17.71 +/- 8.93
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 17.7        |
# | time/                   |             |
# |    total_timesteps      | 160000      |
# | train/                  |             |
# |    approx_kl            | 0.020656658 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.000292    |
# |    loss                 | 45.5        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.0375     |
# |    value_loss           | 95.9        |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 547    |
# |    iterations      | 5      |
# |    time_elapsed    | 299    |
# |    total_timesteps | 163840 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 6           |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.022400396 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.00029     |
# |    loss                 | 37.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 72.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 512        |
# |    iterations           | 7          |
# |    time_elapsed         | 447        |
# |    total_timesteps      | 229376     |
# | train/                  |            |
# |    approx_kl            | 0.02340822 |
# |    clip_fraction        | 0.304      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.4       |
# |    explained_variance   | 0.584      |
# |    learning_rate        | 0.000289   |
# |    loss                 | 23.8       |
# |    n_updates            | 144        |
# |    policy_gradient_loss | -0.0324    |
# |    value_loss           | 54         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 8           |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.019009136 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.000287    |
# |    loss                 | 20.9        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 41.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 9           |
# |    time_elapsed         | 607         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.021847581 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.000285    |
# |    loss                 | 17.5        |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.0273     |
# |    value_loss           | 34.7        |
# -----------------------------------------
# Eval num_timesteps=320000, episode_reward=18.05 +/- 8.10
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 18.1        |
# | time/                   |             |
# |    total_timesteps      | 320000      |
# | train/                  |             |
# |    approx_kl            | 0.018298076 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.000283    |
# |    loss                 | 15.6        |
# |    n_updates            | 216         |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 29.1        |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 451    |
# |    iterations      | 10     |
# |    time_elapsed    | 725    |
# |    total_timesteps | 327680 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 11          |
# |    time_elapsed         | 810         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.018120445 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.441       |
# |    learning_rate        | 0.000281    |
# |    loss                 | 13.3        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 26.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 12          |
# |    time_elapsed         | 893         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.015503273 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.000279    |
# |    loss                 | 10.9        |
# |    n_updates            | 264         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 23.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 13          |
# |    time_elapsed         | 974         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.013644958 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.000277    |
# |    loss                 | 11          |
# |    n_updates            | 288         |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 22.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 14          |
# |    time_elapsed         | 1054        |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.014574598 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.000275    |
# |    loss                 | 11.1        |
# |    n_updates            | 312         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 22.2        |
# -----------------------------------------
# Eval num_timesteps=480000, episode_reward=17.72 +/- 7.28
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 17.7        |
# | time/                   |             |
# |    total_timesteps      | 480000      |
# | train/                  |             |
# |    approx_kl            | 0.013113626 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.000273    |
# |    loss                 | 10.9        |
# |    n_updates            | 336         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 22.8        |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 419    |
# |    iterations      | 15     |
# |    time_elapsed    | 1170   |
# |    total_timesteps | 491520 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 16          |
# |    time_elapsed         | 1249        |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.013070733 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.000271    |
# |    loss                 | 9.98        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 20.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 17          |
# |    time_elapsed         | 1326        |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.010833711 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.00027     |
# |    loss                 | 9.37        |
# |    n_updates            | 384         |
# |    policy_gradient_loss | -0.00909    |
# |    value_loss           | 20.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 419         |
# |    iterations           | 18          |
# |    time_elapsed         | 1406        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.011069933 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.000268    |
# |    loss                 | 10.5        |
# |    n_updates            | 408         |
# |    policy_gradient_loss | -0.00892    |
# |    value_loss           | 20.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 19          |
# |    time_elapsed         | 1487        |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.008173624 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.000266    |
# |    loss                 | 10.4        |
# |    n_updates            | 432         |
# |    policy_gradient_loss | -0.00714    |
# |    value_loss           | 21.5        |
# -----------------------------------------
# Eval num_timesteps=640000, episode_reward=18.20 +/- 8.06
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 18.2        |
# | time/                   |             |
# |    total_timesteps      | 640000      |
# | train/                  |             |
# |    approx_kl            | 0.010916321 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.000264    |
# |    loss                 | 10.7        |
# |    n_updates            | 456         |
# |    policy_gradient_loss | -0.00738    |
# |    value_loss           | 21          |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 411    |
# |    iterations      | 20     |
# |    time_elapsed    | 1594   |
# |    total_timesteps | 655360 |
# -------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 419          |
# |    iterations           | 21           |
# |    time_elapsed         | 1641         |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0100518055 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 0.000262     |
# |    loss                 | 12.7         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00556     |
# |    value_loss           | 22.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 22          |
# |    time_elapsed         | 1692        |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.008563065 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.00026     |
# |    loss                 | 11.4        |
# |    n_updates            | 504         |
# |    policy_gradient_loss | -0.00612    |
# |    value_loss           | 21.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 23           |
# |    time_elapsed         | 1737         |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0101945605 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.561        |
# |    learning_rate        | 0.000258     |
# |    loss                 | 10.4         |
# |    n_updates            | 528          |
# |    policy_gradient_loss | -0.00558     |
# |    value_loss           | 21.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 24          |
# |    time_elapsed         | 1782        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.014480112 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.000256    |
# |    loss                 | 9.73        |
# |    n_updates            | 552         |
# |    policy_gradient_loss | -0.00596    |
# |    value_loss           | 20.6        |
# -----------------------------------------
# Eval num_timesteps=800000, episode_reward=18.83 +/- 9.44
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 18.8        |
# | time/                   |             |
# |    total_timesteps      | 800000      |
# | train/                  |             |
# |    approx_kl            | 0.010139246 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.000254    |
# |    loss                 | 11.6        |
# |    n_updates            | 576         |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 22.3        |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 442    |
# |    iterations      | 25     |
# |    time_elapsed    | 1851   |
# |    total_timesteps | 819200 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 449         |
# |    iterations           | 26          |
# |    time_elapsed         | 1895        |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.010528274 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.000252    |
# |    loss                 | 9.39        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00662    |
# |    value_loss           | 21.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 27          |
# |    time_elapsed         | 1941        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.010567466 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.000251    |
# |    loss                 | 10.2        |
# |    n_updates            | 624         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 21.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 28          |
# |    time_elapsed         | 1990        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.009918025 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.000249    |
# |    loss                 | 10.9        |
# |    n_updates            | 648         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 21.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 29          |
# |    time_elapsed         | 2035        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.010358201 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.000247    |
# |    loss                 | 10.4        |
# |    n_updates            | 672         |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 20.9        |
# -----------------------------------------
# Eval num_timesteps=960000, episode_reward=19.81 +/- 10.01
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 19.8        |
# | time/                   |             |
# |    total_timesteps      | 960000      |
# | train/                  |             |
# |    approx_kl            | 0.008578493 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.000245    |
# |    loss                 | 10.2        |
# |    n_updates            | 696         |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 21.7        |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 467    |
# |    iterations      | 30     |
# |    time_elapsed    | 2102   |
# |    total_timesteps | 983040 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 31          |
# |    time_elapsed         | 2147        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.010382814 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.000243    |
# |    loss                 | 9.8         |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 20.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 32          |
# |    time_elapsed         | 2191        |
# |    total_timesteps      | 1048576     |
# | train/                  |             |
# |    approx_kl            | 0.008331061 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.000241    |
# |    loss                 | 10.5        |
# |    n_updates            | 744         |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 21.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 33          |
# |    time_elapsed         | 2236        |
# |    total_timesteps      | 1081344     |
# | train/                  |             |
# |    approx_kl            | 0.010007218 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.000239    |
# |    loss                 | 10.2        |
# |    n_updates            | 768         |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 21.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 34           |
# |    time_elapsed         | 2280         |
# |    total_timesteps      | 1114112      |
# | train/                  |              |
# |    approx_kl            | 0.0105783595 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.57         |
# |    learning_rate        | 0.000237     |
# |    loss                 | 11.2         |
# |    n_updates            | 792          |
# |    policy_gradient_loss | -0.00544     |
# |    value_loss           | 22.1         |
# ------------------------------------------
# Eval num_timesteps=1120000, episode_reward=19.59 +/- 9.58
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 19.6        |
# | time/                   |             |
# |    total_timesteps      | 1120000     |
# | train/                  |             |
# |    approx_kl            | 0.007221811 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.000235    |
# |    loss                 | 11.3        |
# |    n_updates            | 816         |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 21          |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 488     |
# |    iterations      | 35      |
# |    time_elapsed    | 2347    |
# |    total_timesteps | 1146880 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 36          |
# |    time_elapsed         | 2392        |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.009772448 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.000233    |
# |    loss                 | 9.93        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 21          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 497          |
# |    iterations           | 37           |
# |    time_elapsed         | 2437         |
# |    total_timesteps      | 1212416      |
# | train/                  |              |
# |    approx_kl            | 0.0075468565 |
# |    clip_fraction        | 0.0967       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 0.000232     |
# |    loss                 | 9.7          |
# |    n_updates            | 864          |
# |    policy_gradient_loss | -0.00589     |
# |    value_loss           | 19.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 38          |
# |    time_elapsed         | 2483        |
# |    total_timesteps      | 1245184     |
# | train/                  |             |
# |    approx_kl            | 0.008468294 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.00023     |
# |    loss                 | 10.5        |
# |    n_updates            | 888         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 21.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 39          |
# |    time_elapsed         | 2527        |
# |    total_timesteps      | 1277952     |
# | train/                  |             |
# |    approx_kl            | 0.008471898 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.000228    |
# |    loss                 | 11.3        |
# |    n_updates            | 912         |
# |    policy_gradient_loss | -0.0055     |
# |    value_loss           | 22.5        |
# -----------------------------------------
# Eval num_timesteps=1280000, episode_reward=20.10 +/- 9.67
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 20.1         |
# | time/                   |              |
# |    total_timesteps      | 1280000      |
# | train/                  |              |
# |    approx_kl            | 0.0076391846 |
# |    clip_fraction        | 0.0952       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.593        |
# |    learning_rate        | 0.000226     |
# |    loss                 | 9.44         |
# |    n_updates            | 936          |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 21.9         |
# ------------------------------------------
# New best mean reward!
# --------------------------------
# | time/              |         |
# |    fps             | 505     |
# |    iterations      | 40      |
# |    time_elapsed    | 2594    |
# |    total_timesteps | 1310720 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 41          |
# |    time_elapsed         | 2639        |
# |    total_timesteps      | 1343488     |
# | train/                  |             |
# |    approx_kl            | 0.009090133 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.000224    |
# |    loss                 | 9.79        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 21.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 42          |
# |    time_elapsed         | 2684        |
# |    total_timesteps      | 1376256     |
# | train/                  |             |
# |    approx_kl            | 0.008776676 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.000222    |
# |    loss                 | 10.3        |
# |    n_updates            | 984         |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 21.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 43           |
# |    time_elapsed         | 2729         |
# |    total_timesteps      | 1409024      |
# | train/                  |              |
# |    approx_kl            | 0.0076144566 |
# |    clip_fraction        | 0.09         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.599        |
# |    learning_rate        | 0.00022      |
# |    loss                 | 12           |
# |    n_updates            | 1008         |
# |    policy_gradient_loss | -0.0053      |
# |    value_loss           | 22.1         |
# ------------------------------------------
# Eval num_timesteps=1440000, episode_reward=20.20 +/- 9.62
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 20.2        |
# | time/                   |             |
# |    total_timesteps      | 1440000     |
# | train/                  |             |
# |    approx_kl            | 0.008683477 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.000218    |
# |    loss                 | 11.1        |
# |    n_updates            | 1032        |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 22.3        |
# -----------------------------------------
# New best mean reward!
# --------------------------------
# | time/              |         |
# |    fps             | 515     |
# |    iterations      | 44      |
# |    time_elapsed    | 2796    |
# |    total_timesteps | 1441792 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 519         |
# |    iterations           | 45          |
# |    time_elapsed         | 2839        |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.008466218 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.000216    |
# |    loss                 | 10.7        |
# |    n_updates            | 1056        |
# |    policy_gradient_loss | -0.00554    |
# |    value_loss           | 22          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 46          |
# |    time_elapsed         | 2884        |
# |    total_timesteps      | 1507328     |
# | train/                  |             |
# |    approx_kl            | 0.012728756 |
# |    clip_fraction        | 0.0966      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.000214    |
# |    loss                 | 10.8        |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 21.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 525         |
# |    iterations           | 47          |
# |    time_elapsed         | 2929        |
# |    total_timesteps      | 1540096     |
# | train/                  |             |
# |    approx_kl            | 0.008903839 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.000213    |
# |    loss                 | 8.85        |
# |    n_updates            | 1104        |
# |    policy_gradient_loss | -0.00475    |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 48          |
# |    time_elapsed         | 2973        |
# |    total_timesteps      | 1572864     |
# | train/                  |             |
# |    approx_kl            | 0.008012887 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.000211    |
# |    loss                 | 9.48        |
# |    n_updates            | 1128        |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 19.8        |
# -----------------------------------------
# Eval num_timesteps=1600000, episode_reward=19.81 +/- 9.03
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 19.8        |
# | time/                   |             |
# |    total_timesteps      | 1600000     |
# | train/                  |             |
# |    approx_kl            | 0.007578615 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.000209    |
# |    loss                 | 9.19        |
# |    n_updates            | 1152        |
# |    policy_gradient_loss | -0.00586    |
# |    value_loss           | 21.2        |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 527     |
# |    iterations      | 49      |
# |    time_elapsed    | 3041    |
# |    total_timesteps | 1605632 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 530         |
# |    iterations           | 50          |
# |    time_elapsed         | 3088        |
# |    total_timesteps      | 1638400     |
# | train/                  |             |
# |    approx_kl            | 0.007440198 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.000207    |
# |    loss                 | 9.79        |
# |    n_updates            | 1176        |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 20.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 51           |
# |    time_elapsed         | 3132         |
# |    total_timesteps      | 1671168      |
# | train/                  |              |
# |    approx_kl            | 0.0084224325 |
# |    clip_fraction        | 0.0905       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.586        |
# |    learning_rate        | 0.000205     |
# |    loss                 | 9.9          |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 20.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 536          |
# |    iterations           | 52           |
# |    time_elapsed         | 3176         |
# |    total_timesteps      | 1703936      |
# | train/                  |              |
# |    approx_kl            | 0.0070106494 |
# |    clip_fraction        | 0.0853       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.995       |
# |    explained_variance   | 0.589        |
# |    learning_rate        | 0.000203     |
# |    loss                 | 8.11         |
# |    n_updates            | 1224         |
# |    policy_gradient_loss | -0.00533     |
# |    value_loss           | 19.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 53          |
# |    time_elapsed         | 3219        |
# |    total_timesteps      | 1736704     |
# | train/                  |             |
# |    approx_kl            | 0.008424144 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.000201    |
# |    loss                 | 9.74        |
# |    n_updates            | 1248        |
# |    policy_gradient_loss | -0.0046     |
# |    value_loss           | 18.9        |
# -----------------------------------------
# Eval num_timesteps=1760000, episode_reward=19.66 +/- 9.24
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 19.7        |
# | time/                   |             |
# |    total_timesteps      | 1760000     |
# | train/                  |             |
# |    approx_kl            | 0.007895467 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.000199    |
# |    loss                 | 9.03        |
# |    n_updates            | 1272        |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 18.1        |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 538     |
# |    iterations      | 54      |
# |    time_elapsed    | 3286    |
# |    total_timesteps | 1769472 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 540          |
# |    iterations           | 55           |
# |    time_elapsed         | 3331         |
# |    total_timesteps      | 1802240      |
# | train/                  |              |
# |    approx_kl            | 0.0075393785 |
# |    clip_fraction        | 0.0882       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.859       |
# |    explained_variance   | 0.605        |
# |    learning_rate        | 0.000197     |
# |    loss                 | 9.14         |
# |    n_updates            | 1296         |
# |    policy_gradient_loss | -0.00487     |
# |    value_loss           | 18.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 56          |
# |    time_elapsed         | 3374        |
# |    total_timesteps      | 1835008     |
# | train/                  |             |
# |    approx_kl            | 0.008562782 |
# |    clip_fraction        | 0.0841      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | 0.595       |
# |    learning_rate        | 0.000195    |
# |    loss                 | 8.92        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00562    |
# |    value_loss           | 19.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 546          |
# |    iterations           | 57           |
# |    time_elapsed         | 3418         |
# |    total_timesteps      | 1867776      |
# | train/                  |              |
# |    approx_kl            | 0.0074151545 |
# |    clip_fraction        | 0.0837       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.856       |
# |    explained_variance   | 0.594        |
# |    learning_rate        | 0.000194     |
# |    loss                 | 10.8         |
# |    n_updates            | 1344         |
# |    policy_gradient_loss | -0.00591     |
# |    value_loss           | 20.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 58          |
# |    time_elapsed         | 3465        |
# |    total_timesteps      | 1900544     |
# | train/                  |             |
# |    approx_kl            | 0.007869748 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.000192    |
# |    loss                 | 9.84        |
# |    n_updates            | 1368        |
# |    policy_gradient_loss | -0.00482    |
# |    value_loss           | 21.5        |
# ...
# |    value_loss           | 19.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 135          |
# |    time_elapsed         | 7181         |
# |    total_timesteps      | 4423680      |
# | train/                  |              |
# |    approx_kl            | 0.0037662466 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.459       |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 4.53e-05     |
# |    loss                 | 10.8         |
# |    n_updates            | 3216         |
# |    policy_gradient_loss | -0.00486     |
# |    value_loss           | 21.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 136          |
# |    time_elapsed         | 7225         |
# |    total_timesteps      | 4456448      |
# | train/                  |              |
# |    approx_kl            | 0.0037226654 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | 0.627        |
# |    learning_rate        | 4.34e-05     |
# |    loss                 | 7.76         |
# |    n_updates            | 3240         |
# |    policy_gradient_loss | -0.00449     |
# |    value_loss           | 18.3         |
# ------------------------------------------
# Eval num_timesteps=4480000, episode_reward=20.22 +/- 9.15
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 20.2         |
# | time/                   |              |
# |    total_timesteps      | 4480000      |
# | train/                  |              |
# |    approx_kl            | 0.0036900328 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.452       |
# |    explained_variance   | 0.615        |
# |    learning_rate        | 4.15e-05     |
# |    loss                 | 9.29         |
# |    n_updates            | 3264         |
# |    policy_gradient_loss | -0.0047      |
# |    value_loss           | 19.6         |
# ------------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 615     |
# |    iterations      | 137     |
# |    time_elapsed    | 7290    |
# |    total_timesteps | 4489216 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 138          |
# |    time_elapsed         | 7334         |
# |    total_timesteps      | 4521984      |
# | train/                  |              |
# |    approx_kl            | 0.0038397908 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.444       |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 3.96e-05     |
# |    loss                 | 9.71         |
# |    n_updates            | 3288         |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 19.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 139         |
# |    time_elapsed         | 7378        |
# |    total_timesteps      | 4554752     |
# | train/                  |             |
# |    approx_kl            | 0.003617989 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 3.77e-05    |
# |    loss                 | 10.1        |
# |    n_updates            | 3312        |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 19.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 140          |
# |    time_elapsed         | 7421         |
# |    total_timesteps      | 4587520      |
# | train/                  |              |
# |    approx_kl            | 0.0038338606 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | 0.619        |
# |    learning_rate        | 3.58e-05     |
# |    loss                 | 8.63         |
# |    n_updates            | 3336         |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 19.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 141          |
# |    time_elapsed         | 7465         |
# |    total_timesteps      | 4620288      |
# | train/                  |              |
# |    approx_kl            | 0.0034549502 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.436       |
# |    explained_variance   | 0.614        |
# |    learning_rate        | 3.39e-05     |
# |    loss                 | 7.86         |
# |    n_updates            | 3360         |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 18.9         |
# ------------------------------------------
# Eval num_timesteps=4640000, episode_reward=21.06 +/- 9.73
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 21.1        |
# | time/                   |             |
# |    total_timesteps      | 4640000     |
# | train/                  |             |
# |    approx_kl            | 0.003980765 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.432      |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 3.2e-05     |
# |    loss                 | 10.2        |
# |    n_updates            | 3384        |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 19.7        |
# -----------------------------------------
# New best mean reward!
# --------------------------------
# | time/              |         |
# |    fps             | 617     |
# |    iterations      | 142     |
# |    time_elapsed    | 7530    |
# |    total_timesteps | 4653056 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 143          |
# |    time_elapsed         | 7574         |
# |    total_timesteps      | 4685824      |
# | train/                  |              |
# |    approx_kl            | 0.0030910363 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.432       |
# |    explained_variance   | 0.618        |
# |    learning_rate        | 3.01e-05     |
# |    loss                 | 9.92         |
# |    n_updates            | 3408         |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 20.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 619          |
# |    iterations           | 144          |
# |    time_elapsed         | 7618         |
# |    total_timesteps      | 4718592      |
# | train/                  |              |
# |    approx_kl            | 0.0031507476 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.43        |
# |    explained_variance   | 0.616        |
# |    learning_rate        | 2.82e-05     |
# |    loss                 | 9.66         |
# |    n_updates            | 3432         |
# |    policy_gradient_loss | -0.00489     |
# |    value_loss           | 18.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 145          |
# |    time_elapsed         | 7661         |
# |    total_timesteps      | 4751360      |
# | train/                  |              |
# |    approx_kl            | 0.0030283923 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.427       |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 2.63e-05     |
# |    loss                 | 8.29         |
# |    n_updates            | 3456         |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 18.8         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 620        |
# |    iterations           | 146        |
# |    time_elapsed         | 7704       |
# |    total_timesteps      | 4784128    |
# | train/                  |            |
# |    approx_kl            | 0.00266399 |
# |    clip_fraction        | 0.0251     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.441     |
# |    explained_variance   | 0.612      |
# |    learning_rate        | 2.44e-05   |
# |    loss                 | 9.49       |
# |    n_updates            | 3480       |
# |    policy_gradient_loss | -0.00438   |
# |    value_loss           | 18.9       |
# ----------------------------------------
# Eval num_timesteps=4800000, episode_reward=20.57 +/- 9.38
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 20.6        |
# | time/                   |             |
# |    total_timesteps      | 4800000     |
# | train/                  |             |
# |    approx_kl            | 0.002799708 |
# |    clip_fraction        | 0.0265      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 2.25e-05    |
# |    loss                 | 10.2        |
# |    n_updates            | 3504        |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 19.3        |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 619     |
# |    iterations      | 147     |
# |    time_elapsed    | 7771    |
# |    total_timesteps | 4816896 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 148          |
# |    time_elapsed         | 7814         |
# |    total_timesteps      | 4849664      |
# | train/                  |              |
# |    approx_kl            | 0.0027808752 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.441       |
# |    explained_variance   | 0.603        |
# |    learning_rate        | 2.06e-05     |
# |    loss                 | 9.58         |
# |    n_updates            | 3528         |
# |    policy_gradient_loss | -0.00425     |
# |    value_loss           | 20.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 149          |
# |    time_elapsed         | 7858         |
# |    total_timesteps      | 4882432      |
# | train/                  |              |
# |    approx_kl            | 0.0025284193 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.435       |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 1.87e-05     |
# |    loss                 | 9.28         |
# |    n_updates            | 3552         |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 19.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 150          |
# |    time_elapsed         | 7901         |
# |    total_timesteps      | 4915200      |
# | train/                  |              |
# |    approx_kl            | 0.0023884638 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.441       |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 1.68e-05     |
# |    loss                 | 9.21         |
# |    n_updates            | 3576         |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 19.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 151         |
# |    time_elapsed         | 7944        |
# |    total_timesteps      | 4947968     |
# | train/                  |             |
# |    approx_kl            | 0.002250371 |
# |    clip_fraction        | 0.0179      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.437      |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 1.49e-05    |
# |    loss                 | 10.4        |
# |    n_updates            | 3600        |
# |    policy_gradient_loss | -0.00364    |
# |    value_loss           | 20.8        |
# -----------------------------------------
# Eval num_timesteps=4960000, episode_reward=20.93 +/- 9.46
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 20.9         |
# | time/                   |              |
# |    total_timesteps      | 4960000      |
# | train/                  |              |
# |    approx_kl            | 0.0023927488 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.429       |
# |    explained_variance   | 0.616        |
# |    learning_rate        | 1.3e-05      |
# |    loss                 | 8.63         |
# |    n_updates            | 3624         |
# |    policy_gradient_loss | -0.00393     |
# |    value_loss           | 17.9         |
# ------------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 621     |
# |    iterations      | 152     |
# |    time_elapsed    | 8010    |
# |    total_timesteps | 4980736 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 153          |
# |    time_elapsed         | 8054         |
# |    total_timesteps      | 5013504      |
# | train/                  |              |
# |    approx_kl            | 0.0018740813 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.446       |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 1.11e-05     |
# |    loss                 | 10.5         |
# |    n_updates            | 3648         |
# |    policy_gradient_loss | -0.00351     |
# |    value_loss           | 21.2         |
# ------------------------------------------

# %%
model.save(r"C:\Users\kubaw\Desktop\DELFT\THESIS\CODE\TEST_MODELS\baterytrina24_high_")

# %%
#model = PPO.load(r"C:\Users\kubaw\Desktop\DELFT\THESIS\CODE\TEST_MODELS\bateryJA24\best_model.zip")

# %%
evaluate1(1, env_test, model)
# Out:
# Act: [12  0]
#  Obs: [0.9873385  0.8577553  0.92364246 0.8684109  0.9917868  0.93270177
#  0.8611209  0.9986229  0.98365194 0.9821843  0.8793439  0.900826
#  0.9812651  0.9872371  0.9269218  0.98619074 0.99129    0.9015927
#  0.8918074  0.9977231  0.98882157 0.8711458  0.9067533  0.9924551
#  0.09120543 0.08876099 0.00876541 0.26855278 0.21556297 0.06014763
#  0.3688     0.         0.24433249]
#  Balance 309.72761288268293
# Act: [0 0]
#  Obs: [0.9733854  0.85080546 0.91454    0.8582409  0.97990876 0.91184354
#  0.85832554 0.99697375 0.97094905 0.97110844 0.86932915 0.9020662
#  0.983444   0.9723692  0.91131055 0.97942173 0.96984    0.8942644
#  0.8753438  0.98821723 0.97617286 0.867638   0.8948084  0.9788829
#  0.09497126 0.09098997 0.00943227 0.2587641  0.04660992 0.06375648
#  0.0608     0.         0.24354868]
#  Balance 988.059467291343
# Act: [0 0]
#  Obs: [0.96761733 0.82957345 0.89367026 0.854353   0.9706752  0.89915997
#  0.8495043  0.99555904 0.9547409  0.9449344  0.8513423  0.89121217
#  0.96666974 0.9624315  0.89145607 0.97030413 0.9510253  0.8882859
#  0.8650376  0.9851922  0.97378594 0.8519773  0.89130825 0.9656974
#  0.12759718 0.06886689 0.00943309 0.25774446 0.04754212 0.
#  0.6664     0.         0.19676328]
#  Balance 967.791133842989
# Act: [0 0]
#  Obs: [0.95093983 0.8133613  0.8848955  0.8435608  0.96098244 0.8937124
#  0.82263094 0.98678046 0.9532828  0.9425726  0.8413798  0.8788575
#  0.9460788  0.953774   0.8849911  0.9591397  0.93561137 0.8888511
#  0.85215515 0.9739857  0.96556187 0.84297484 0.8735428  0.953278
#  0.12746169 0.08951508 0.03805054 0.2624605  0.04849296 0.
#  0.5056     0.         0.17834032]
#  Balance 1270.9550245419505
# Act: [0 0]
#  Obs: [0.9330384  0.80256873 0.8710775  0.83712566 0.9582567  0.88170654
#  0.81171584 0.9760556  0.9493456  0.9312724  0.82040143 0.87590647
#  0.93955433 0.9367515  0.8689219  0.93929315 0.9169602  0.870355
#  0.842633   0.96494913 0.9661417  0.82929134 0.8680528  0.93072027
#  0.13400945 0.050344   0.03887484 0.23300336 0.04946282 0.
#  0.6208     0.         0.12927395]
#  Balance 1433.497863666804
# Act: [0 0]
#  Obs: [0.9258028  0.78772956 0.8615607  0.82317305 0.9538753  0.8731656
#  0.7943179  0.96812576 0.93425715 0.92022663 0.8054824  0.8776037
#  0.9310899  0.9217798  0.860488   0.93266606 0.90929866 0.8638185
#  0.8414347  0.9566003  0.94673496 0.82284546 0.8636515  0.9277344
#  0.14887017 0.04543461 0.03887484 0.21596205 0.05045208 0.
#  0.1152     0.         0.1480311 ]
#  Balance 1065.2541666543666
# Act: [0 0]
#  Obs: [0.9060912  0.78085524 0.8450251  0.         0.93099433 0.8637454
#  0.76811934 0.9581224  0.92930716 0.91388476 0.79118854 0.87897414
#  0.92760915 0.91136944 0.852439   0.90775853 0.8954172  0.852969
#  0.8249717  0.         0.93295336 0.8155421  0.85545224 0.9196866
#  0.18274862 0.05577419 0.03887485 0.21214065 0.05146112 0.
#  0.5752     0.         0.16485696]
#  Balance 1040.8828569921052
# Act: [1 0]
#  Obs: [0.894498   0.77635586 0.83917564 0.99780345 0.9162149  0.84447026
#  0.7538383  0.9480289  0.         0.89196765 0.78065985 0.8761001
#  0.916283   0.9023867  0.8341329  0.9061845  0.87955004 0.8390691
#  0.8091635  0.         0.92035943 0.794849   0.8365578  0.9081561
#  0.16721533 0.05103349 0.03888048 0.18887176 0.0794981  0.
#  0.2176     0.         0.16432494]
#  Balance 911.7206713000191
# Act: [0 0]
#  Obs: [0.8847526  0.         0.82687575 0.98443544 0.9042761  0.8415083
#  0.7469385  0.93866026 0.         0.87558603 0.76974046 0.8706843
#  0.8953964  0.8941744  0.81060445 0.8892155  0.87066936 0.8251694
#  0.80624306 0.         0.9054675  0.79075843 0.82422024 0.89994407
#  0.16965978 0.05177952 0.11237261 0.17820153 0.04907847 0.
#  0.7896     0.         0.16870633]
#  Balance 1033.5533266203768
# Act: [7 0]
#  Obs: [0.87579376 1.0017956  0.         0.9777564  0.8900097  0.83169204
#  0.99745977 0.92817223 0.99851894 0.8587908  0.99427545 0.85674554
#  0.8928584  0.89649904 0.77891487 0.88263744 0.8648855  0.
#  1.008058   0.9951818  0.893919   1.0105373  0.81125325 0.87392205
#  0.20225433 0.06172726 0.12110022 0.16271606 0.20078307 0.
#  0.8016     0.         0.19062869]
#  Balance -138.1733962612302
# Act: [2 0]
#  Obs: [0.86795175 0.9871458  1.0169854  0.9819872  0.87806445 0.
#  0.9806398  0.9148457  0.98363066 0.8476328  0.9837264  0.8536741
#  0.8907277  0.8885319  0.         0.8679104  0.84994256 1.0058656
#  1.0068918  0.9855896  0.8828103  0.99552155 0.80841124 0.861287
#  0.1903885  0.05810585 0.12110022 0.14458601 0.11262379 0.
#  0.5768     0.         0.20221944]
#  Balance 849.4493259118469
# Act: [0 0]
#  Obs: [0.85775197 0.9790473  1.0136342  0.983069   0.8631102  0.
#  0.9774063  0.         0.9736426  0.8355849  0.9739231  0.8520948
#  0.8859831  0.88042647 0.         0.8603942  0.8530098  0.9862621
#  1.0054457  0.96440005 0.86993814 0.9801727  0.7955427  0.841255
#  0.16593418 0.05064249 0.12134678 0.12864935 0.05208246 0.
#  0.4344     0.         0.19289815]
#  Balance 1203.7984257205567
# Act: [0 0]
#  Obs: [0.8501759  0.9720763  0.9977588  0.9702846  0.8631401  0.
#  0.97181773 0.         0.9646066  0.81652915 0.9688146  0.8358081
#  0.86672527 0.86592996 0.         0.8448646  0.8468254  0.9756854
#  1.0002456  0.9546963  0.85992473 0.972332   0.         0.82260334
#  0.2309069  0.07047191 0.12134678 0.11987404 0.05070938 0.
#  0.6328     0.         0.21007442]
#  Balance 1021.8478341200981
# Act: [1 0]
#  Obs: [0.8457033  0.9703251  0.97711796 0.9562398  0.         0.
#  0.9657069  0.         0.9548675  0.80578876 0.9586143  0.
#  0.86480856 0.8552534  1.0152758  0.8351661  0.83502334 0.9611694
#  0.98741484 0.9364633  0.         0.96108    0.         0.8145781
#  0.23271862 0.07102484 0.12141124 0.12092184 0.08160646 0.
#  0.332      0.         0.23006096]
#  Balance 1078.6281064711732
# Act: [1 0]
#  Obs: [0.         0.9551791  0.9733667  0.94958025 0.         0.
#  0.9402913  0.         0.9442282  0.         0.9529422  1.0015701
#  0.         0.8450237  1.0049772  0.82858145 0.81636745 0.9469708
#  0.         0.9227364  0.         0.94900495 0.         0.80346715
#  0.22949868 0.07004213 0.12161507 0.10416699 0.07807785 0.
#  0.7328     0.         0.2472684 ]
#  Balance 997.692072464768
# Act: [13  0]
#  Obs: [1.0124555  0.94517946 0.95828384 0.9419882  1.01439    1.0008013
#  0.9272079  1.0123096  0.9336572  1.0029656  0.9424138  0.995005
#  0.9986754  1.008739   0.983182   1.0220207  1.0030117  0.9414695
#  1.0040072  0.91380876 1.0084901  0.94969124 0.997873   0.99974537
#  0.20620596 0.06293328 0.12187387 0.09622219 0.32977378 0.0518391
#  0.6048     0.         0.22968014]
#  Balance -812.1334308687501
# Act: [0 0]
#  Obs: [0.9996747  0.93629235 0.9529916  0.92951345 0.99224365 0.98212534
#  0.         1.0008008  0.9253773  0.97824585 0.9408847  0.977716
#  0.9871277  1.0052167  0.9695484  1.0148364  0.98346674 0.9347086
#  0.99460846 0.9016811  0.99907166 0.9360398  0.9874773  0.9851994
#  0.19183543 0.05854745 0.12187387 0.09393214 0.06273082 0.05494945
#  0.7176     0.         0.20597686]
#  Balance 1064.32643653203
# Act: [0 0]
#  Obs: [0.9989769  0.91833186 0.9499926  0.9280503  0.9846116  0.97556406
#  0.         0.9976994  0.915193   0.97150433 0.9332803  0.97126967
#  0.9674896  0.9917733  0.95870763 1.0101647  0.96939427 0.9154573
#  0.9793217  0.89070356 0.986443   0.922438   0.9799028  0.97816026
#  0.20117839 0.06139888 0.16645336 0.06747858 0.06131937 0.
#  0.7848     0.         0.18235393]
#  Balance 878.0356333310868
# Act: [0 0]
#  Obs: [0.9899734  0.         0.94078183 0.92058676 0.9770523  0.9644766
#  0.         0.97772074 0.         0.9653657  0.91543436 0.9610334
#  0.9587983  0.9699071  0.9483942  0.         0.95243317 0.90018576
#  0.96839106 0.8737507  0.96264493 0.92078954 0.9785716  0.9724913
#  0.20785336 0.06343606 0.16645336 0.0615756  0.06254576 0.
#  0.0736     0.         0.14619419]
#  Balance 1289.4235153864893
# Act: [0 0]
#  Obs: [0.9818183  0.         0.         0.9077992  0.9672954  0.95205826
#  0.         0.9759779  0.         0.9593507  0.89626443 0.9482643
#  0.95373213 0.9630315  0.94172424 0.         0.9287406  0.89209217
#  0.9665399  0.8738882  0.9412867  0.9149129  0.97798675 0.9700866
#  0.24644804 0.07521501 0.17033237 0.0556524  0.05547537 0.
#  0.9112     0.         0.13861342]
#  Balance 1180.6861379263269
# Act: [6 0]
#  Obs: [0.9702298  1.0078832  1.0174388  0.8975528  0.95522517 0.950742
#  1.0166345  0.9718978  1.0193522  0.94408935 0.8788433  0.
#  0.9447197  0.9609784  0.933483   1.0140051  0.92025673 0.87589765
#  0.9532759  1.0197383  0.93469226 0.89138347 0.9736432  0.9561431
#  0.26645765 0.08132187 0.1703324  0.04819106 0.22763138 0.
#  0.0152     0.         0.0945349 ]
#  Balance 158.7594635015189
# Act: [0 0]
#  Obs: [0.9576203  0.99788225 1.0117017  0.89346254 0.94799286 0.940332
#  1.0043463  0.9683629  1.0058471  0.9321465  0.8702217  0.
#  0.9366257  0.94549185 0.9301836  1.005566   0.90858793 0.8587024
#  0.9381169  1.0009905  0.         0.88567317 0.9632215  0.9491632
#  0.32870844 0.10032058 0.18077514 0.03728998 0.06637406 0.
#  0.2424     0.         0.08629223]
#  Balance 1622.2851785771431
# Act: [0 0]
#  Obs: [0.94319016 0.98578465 0.99476546 0.9007741  0.9254968  0.92363405
#  1.0015749  0.         0.9903084  0.9251647  0.85367674 0.
#  0.         0.931286   0.9170034  0.9969243  0.88808495 0.8481016
#  0.9291214  0.9908951  0.         0.8770152  0.9630787  0.944208
#  0.3146161  0.09601966 0.18077514 0.02818455 0.064758   0.
#  0.8704     0.         0.07422349]
#  Balance 1878.908015496189
# Act: [1 1]
#  Obs: [0.9395154  0.96774    0.97991353 0.8876216  0.9189594  0.90908974
#  0.9915879  0.         0.9795708  0.90855587 0.         1.0152209
#  0.         0.         0.9075348  0.990279   0.86393446 0.8408432
#  0.         0.9734796  0.         0.8683245  0.9489302  0.93953925
#  0.363144   0.11083018 0.18166716 0.01306815 0.37701842 0.03534463
#  0.9184     0.9855     0.06981371]
#  Balance -183.59941118943198
# Act: [0 0]
#  Obs: [0.         0.9513698  0.9625132  0.8837158  0.9089334  0.9055546
#  0.9806588  0.         0.96702904 0.91538054 0.         1.0014509
#  0.         0.         0.8881615  0.9795003  0.8590926  0.83812284
#  0.         0.9514195  0.         0.8622119  0.93478286 0.9277187
#  0.363144   0.11083018 0.18166716 0.01306815 0.05512436 0.03746532
#  0.276      0.971      0.06981371]
#  Balance 2540.314727029713
# total financial balance: (eur) 23651.690757942164 internal rate of return 53.06023418340982

# %%
def evaluate2(episodes, environment, model):
    
    mean_irr = 0
    mean_fin_balance = 0
    irr = 0
    fin_balance = 0
    count = 0
    irr_count = 0
    npv = 0

    for ep in range(episodes):

        obs, _ = environment.reset()  # Unpack the tuple and ignore the info part
        done = False

        while not done:
            action, _ = model.predict(obs)  # Now obs is just the observation array
            obs, reward, done, truncated, info = environment.step(action)
            # Extracting the 2nd and 3rd key-value pairs
            keys = list(info.keys())
            values = list(info.values())

            # Getting the 2nd key-value pair
            second_value = values[1]
            # Getting the 3rd key-value pair
    
            fourth_value = values[4]
        
        fin_balance += second_value
        npv += fourth_value
        count += 1

    mean_fin_balance = fin_balance/count
    mean_npv = npv/count
    
    print(mean_npv, "\n", mean_irr, "\n" )

    environment.close()

# %%
evaluate2(10000, env_test, model)
# Out:
# 10448.729321015973
#  0

# %%
def basepolicy1(episodes, environment, number_of_panels):
    
    mean_irr = 0
    mean_fin_balance = 0
    irr = 0
    fin_balance = 0
    count = 0
    irr_count = 0
    npv = 0

    for ep in range(episodes):

        obs, _ = environment.reset()  # Unpack the tuple and ignore the info part
        done = False
        
        action = [0, 0]
    

        while not done:
            action[0] = 0
            action[1] = 0
            for i, n in enumerate(obs):
                if i < number_of_panels:
                    if n < 0.7:
                        action[0] += 1
            
            if obs[[31]] == 0:
                action[1] = 1
                
                
            obs, reward, done, truncated, info = environment.step(action)

            # Extracting the 2nd and 3rd key-value pairs
            keys = list(info.keys())
            values = list(info.values())

            # Getting the 2nd key-value pair
            second_value = values[1]

            # Getting the 3rd key-value pair
    
            third_value = values[2]
            fourth_value = values[4]
        
        fin_balance += second_value
        npv += fourth_value
        count += 1
            
    mean_fin_balance = fin_balance/count
    mean_npv = npv/count

    print(mean_npv, "\n", mean_irr, "\n" )

    environment.close()

# %%
basepolicy1(10000, env_test, 24)
# Out:
# 2712.953634356207
#  0

# %%
# import and modify data

# Assuming the file is a CSV and specifying the correct path and filename
file_path = r"C:\Users\kubaw\Desktop\DELFT\THESIS\CH5"

# Use pandas to read the CSV file
AC_OUTPUT = pd.read_csv(file_path + "/AC_OUTPUT_SunPower")
elec_df = pd.read_csv(file_path + "/hourly_consumption_gemany.csv")
import_price = pd.read_csv(file_path + "/electricity_tariff.csv")

#elec_df = elec_df * 1000
elec_df = elec_df.drop('HourOfYear', axis=1)

elec_df['hour_of_day'] = np.arange(8760) % 24
elec_df['day_of_week'] = np.arange(8760) // 24 % 7  # 0 is Monday, 6 is Sunday

# Define rates
peak_rate = 1.45
normal_rate = 1
off_peak_rate = 0.85

# Function to determine rate based on hour and day
def determine_rate(hour, day):
    if day < 5:  # Monday to Friday
        if 16 <= hour < 21:  # 4pm to 9pm
            return peak_rate
        elif 6 <= hour < 10:  # 7am to 9am and 10am to 3pm
            return normal_rate
        else:  # Off-peak times
            return off_peak_rate
    else:  # Weekend
        if 16 <= hour < 21:  # 4pm to 9pm
            return normal_rate
        else:  # Off-peak times
            return off_peak_rate
    
# Apply the function to each row to determine the rate
elec_df['rate'] = elec_df.apply(lambda row: determine_rate(row['hour_of_day'], row['day_of_week']), axis=1)

import_price_df = import_price.drop(columns=['x'])
import_price_df = import_price_df[:-26]

train_cols = random.sample(list(import_price_df.columns), 7000)
import_price_train = import_price_df[train_cols]
test_cols = [col for col in import_price_df.columns if col not in train_cols]
import_price_test = import_price_df[test_cols]

Eff = pd.read_csv(file_path + "/Efficency_impr")
Eff = (Eff)/100 + 1

CAPEX = pd.read_csv(file_path + "/CAPEX_MAX.csv")
CAPEX_JA = (CAPEX[:26])

train_cols_CAPEX = random.sample(list(CAPEX_JA.columns), 7000)
test_cols_CAPEX = [col for col in CAPEX_JA.columns if col not in train_cols_CAPEX]

CAPEX_JA_train = CAPEX_JA[train_cols_CAPEX]
CAPEX_JA_test = CAPEX_JA[test_cols_CAPEX]

train_cols_Eff = random.sample(list(Eff.columns), 7000)
test_cols_Eff = [col for col in Eff.columns if col not in train_cols_Eff]

Eff_train = Eff[train_cols_Eff]
Eff_test = Eff[test_cols_Eff]

AC_OUTPUT_arr = (np.array(AC_OUTPUT.T)).flatten()

Eff_train_arr = np.array(Eff_train.T)
Eff_test_arr = np.array(Eff_test.T)

CAPEX_JA_train_arr = np.array(CAPEX_JA_train.T)
CAPEX_JA_test_arr = np.array(CAPEX_JA_test.T)

elec_consum_arr = np.array(elec_df["Consumption"])
import_price_rate = np.array(elec_df["rate"])

import_price_train_arr = np.array(import_price_train.T)
import_price_test_arr = np.array(import_price_train.T)

file_path2 = r"C:\Users\kubaw\Desktop\DELFT\THESIS\CH6"

Battery_CAPEX = pd.read_csv(file_path2 + "/batery_CAPES.csv")
Battery_CAPEX = (Battery_CAPEX[:26])


train_cols_Battery_CAPEX = random.sample(list(Battery_CAPEX.columns), 7000)
test_cols_Battery_CAPEX = [col for col in Battery_CAPEX.columns if col not in train_cols_Battery_CAPEX]

Battery_CAPEX_train = Battery_CAPEX[train_cols_Battery_CAPEX]
Battery_CAPEX_test = Battery_CAPEX[test_cols_Battery_CAPEX]

Battery_CAPEX_train_arr = np.array(Battery_CAPEX_train.T)
Battery_CAPEX_test_arr = np.array(Battery_CAPEX_test.T)

# %%
class TrainEnvironment(gym.Env):
    def __init__(self, AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_tariff, efficency, CAPEX, Battery_CAPEX):
        
        # Price per watthour
        self.import_price_df = import_tariff
        self.import_price_at_zero = np.float32(0.00035)
        self.import_price_rate = import_price_rate
        
        # Energy Balance
        self.AC_OUTPUT = AC_OUTPUT_arr
        self.elec_df = elec_consum_arr
        self.max_export = 4000
        self.number_of_panels = 24
        
        # Degradation
        self.deg_mu = 1.055
        self.deg_std = 0.555
        
        # Efficency Development
        self.efficency_develop_df = efficency
        self.efficency_at_zero = 1.0
        
        # Costs
        self.power_at_zero = 415
        self.cost_per_Wp_df_at_zero = 0.69
        self.cost_per_Wp_df = CAPEX
        self.initial_other_costs = 150
        
        self.operational_cost = 16.8
        #self.budget_constraint = 1500
        
        self.loan_interest_rate = 1.06
        self.normal_interest_rate = 1.02
        
        self.battery_CAPEX = Battery_CAPEX
        self.battery_CAPEX_at_zero = 1
        
        self.possible_batery_sizes = 1
                        
        # Spaces and length
        self.action_space = spaces.MultiDiscrete([self.number_of_panels + 1, 2])
        
        self.observation_space = spaces.Box(0, 1.25, shape=(self.number_of_panels + 7 + 2,))
        self.episode_len = 25
        self.months_per_timestep = 12
        
    def _get_obs(self):
        
        return self.observation
    
    def calculate_import_export(self, AC_OUTPUT, elec_df, export_price, import_price):
        
        """
        Calculate the annual Wh of energy exported to the grid (exported) and saved (minimised)
        """
        
        batery_state = 1
        minimised_mult = 1
        export_mult = 1
        if self.battery_state > 0 and self.battery_state <=1:
            minimised_mult = 2.155
            export_mult = 0.52
            batery_state = self.battery_state
        
        AC_OUTPUT_tot = self._get_obs()[0:self.number_of_panels].sum() * self.AC_OUTPUT 

        exported = (AC_OUTPUT_tot - self.elec_df).clip(min=0, max = self.max_export)        
        export_revenue = (export_price * exported).sum() * export_mult

        
        minimised = AC_OUTPUT_tot - exported 
        minimised_revenue = (minimised * (self.import_price_rate * import_price)).sum() * minimised_mult * batery_state
        

        return export_revenue, AC_OUTPUT_tot, minimised_revenue    
    
    def reset(self, seed=None):
        
        """
        Reset the environment to the original state at t=1
        """
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)
        
        # Panels
        self.init_obs = np.random.uniform(0, 1, size=self.number_of_panels).astype(np.float32)
        self.init_obs = np.where(self.init_obs < 0.5, 0.0, np.random.uniform(0.85, 1.0, size=self.number_of_panels))

        # Combine all initialization into a single step for efficiency
        self.import_price_at_zero_norm = (self.import_price_at_zero - 0.00022499) / (0.0020798 - 0.00022499)
        self.FiT_at_zero_norm = (self.import_price_at_zero - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
        self.efficency_at_zero_norm = (self.efficency_at_zero - 0.999) / (1.156 - 0.999)
        self.panel_cost_and_inverter_at_zero_norm = (self.cost_per_Wp_df_at_zero - 0.1712159) / (0.8214356 - 0.1712159)
        
        self.current_budget_constraint = np.random.randint(0, 750)
        self.next_step_budget_constraint = 0
        
        self.battery_CAPEX_at_zero_norm = (self.battery_CAPEX_at_zero - 0.03) / (4 - 0.03)
        
        # Complete observation initialization in one go
        self.observation = np.concatenate([
            self.init_obs,
            [self.import_price_at_zero_norm, self.FiT_at_zero_norm, self.efficency_at_zero_norm, 
             self.panel_cost_and_inverter_at_zero_norm, 0., 0., 0., 0., self.battery_CAPEX_at_zero_norm]
        ]).astype(np.float32)

        self.previous_observation = self.observation.copy()

        # RANDOM IMPORT PRICE
        self.random_import_price = self.import_price_df[np.random.choice(self.import_price_df.shape[0])] 

        # RANDOM EFFICENCY
        self.random_efficency_develop = self.efficency_develop_df[np.random.choice(self.efficency_develop_df.shape[0])]   
        
        # RANDOM COST PER WP
        self.random_cost_per_Wp = self.cost_per_Wp_df[np.random.choice(self.cost_per_Wp_df.shape[0])]   
        
        self.random_battery_CAPEX = self.battery_CAPEX[np.random.choice(self.battery_CAPEX.shape[0])]
        
        self.episode_len = 25  
    
        info = {}
        
        # RESET BALANCES
        self.fin_balance_tot = 0
        self.reward_tot = 0
        self.env_balance_tot = 0
        self.produced = 0
        self.other_costs = 0
        self.FiT = 0.0004
        self.next_FiT = 0.0004

        self.total_cash_flow = []
        self.annual_cash_flow = 0
                
        self.due_loans = [0, 0, 0, 0] 
        self.current_interest = 0
        self.step_total_interest = 1
        self.survival = np.zeros(self.number_of_panels, dtype=np.float32)
        self.resale_values = array_of_zeros = np.zeros(self.number_of_panels, dtype=np.float32)
        
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)
        
        self.two_year_ago_interest = 0
        self.first_year_interest = []
        self.second_year_interest = [0]
        self.third_year_interest = [0, 0]
        self.fourth_year_interest = [0, 0, 0]
        self.next_year_total = 0
        
        self.battery_state = 0
        
        self.survival = np.zeros(self.number_of_panels, dtype=np.float32)
    
        return self.observation, info
    
    def calculate_resale(self, initial_panel_cost, indices):
        
        self.resale_values[indices] = initial_panel_cost
        
        self.resale_values = self.resale_values * 0.85
        
        for count, i in enumerate(self.broke):
            if i == 1:
                self.resale_values[count] = 0
        
        resale_step = self.resale_values[indices].sum()
        
        return resale_step
    
    def calculate_panel_inv_cost(self, cost_per_Wp):
        
        PW_ep = self.efficency_develop * self.power_at_zero
        
        panel_cost_and_inverter = PW_ep * cost_per_Wp
        
        return panel_cost_and_inverter
        
    def calculate_penalty(self, current_step, annual_expense):
              
        year = 25 - current_step
        
        if year > 0:
            self.current_budget_constraint = self.next_step_budget_constraint    
            
        
        self.current_interest = self.next_year_total
        annual_expense = (-annual_expense)
        value = 0 
        loan = 0
        annual_interest = 0

        if annual_expense > self.current_budget_constraint:
            loan = (self.current_budget_constraint - annual_expense)
            value = annual_expense / self.current_budget_constraint
            periods = 2 if value < 2 else 3 if value < 3 else 4

            annual_interest = loan / periods
            interest_multiplier = 1

            for i in range(4):
                if i < periods:
                    self.due_loans[i] = annual_interest * interest_multiplier
                    interest_multiplier *= self.loan_interest_rate
                else:
                    self.due_loans[i] = 0
        else:
             self.due_loans = [0, 0, 0, 0]
    
        self.first_year_interest.append(self.due_loans[0])
        self.second_year_interest.append(self.due_loans[1])
        self.third_year_interest.append(self.due_loans[2])
        self.fourth_year_interest.append(self.due_loans[3])
    
    
        self.next_year_total = self.first_year_interest[year] + self.second_year_interest[year] + self.third_year_interest[year] + self.fourth_year_interest[year]
        
        self.next_step_budget_constraint = np.random.randint(0, 750) * self.step_total_interest
        current_budget_observation = (self.next_step_budget_constraint - 0 * self.step_total_interest) / (750 * self.step_total_interest - 0 * self.step_total_interest) 
        self.observation[self.number_of_panels + 6] = current_budget_observation
                
        return self.current_interest, self.due_loans, self.next_year_total
        
    def calculate_total_CAPEX(self, action_step, panel_cost_and_inverter):
        """
        Calculate CAPEX each step in a vectorized manner.
        """
        BOS = panel_cost_and_inverter * 0.55
        number_installed = int(np.sum(action_step))

        # Calculate costs from module and inverter
        panel_cost_and_inverter_step = panel_cost_and_inverter * number_installed

        # Calculate other installation costs
        if number_installed == 0:
            other_costs = 0
        elif number_installed == 1:
            other_costs = self.initial_other_costs * self.step_total_interest
        else:
            discounts = 0.9 ** np.arange(number_installed)
            other_costs = (self.initial_other_costs * self.step_total_interest * discounts).sum()

        # Calculate BOS costs using vector operations
        is_new_installation = (self.previous_observation[:number_installed] == 0) & (action_step[:number_installed] == 1)
        is_replacement = (self.previous_observation[:number_installed] > 0) & (action_step[:number_installed] == 1)
        BOS_cost = np.sum(BOS * is_new_installation) + np.sum((BOS / 2) * is_replacement)

        # Sum total CAPEX
        total_CAPEX = panel_cost_and_inverter_step + BOS_cost + other_costs

        return total_CAPEX, panel_cost_and_inverter
        
    def failure(self, actions):
        
        beta = 3  # Shape parameter
        phi = 50  # Scale parameter  

        # Determine which panels are active based on the actions and previous observations.
        if self.episode_len == 24:
            active_panels = (self.observation[:self.number_of_panels] > 0.85)
        else:
            active_panels = (self.observation[:self.number_of_panels] == self.efficency_develop)

        # Calculate lifespan for all active panels at once
        lifespans = np.random.weibull(beta, self.number_of_panels) * phi
        lifespans = np.where(active_panels, lifespans, 0)  # Apply lifespan only to active panels

        # Adjust survival times based on episode length
        self.survival[:self.number_of_panels] = np.where(
            active_panels,
            np.abs(lifespans.astype(int)) + np.abs(self.episode_len - 25),
            self.survival[:self.number_of_panels]
        )

        return self.survival

    def calculate_FiT(self, episodes, import_price):
            
        self.FiT = import_price
            
        if episodes == 25:
            self.FiT = self.FiT
            
        elif episodes == 24 or episodes == 23:
            self.FiT = self.FiT * 0.64
            
        elif episodes == 22:
            self.FiT = self.FiT * 0.46
            
        elif episodes == 21:
            self.FiT = self.FiT * 0.55
            
        elif episodes < 20:
            self.FiT = self.FiT * 0.33
            
        elif episodes == 20:
            self.FiT = self.FiT * 0.37
            
        return self.FiT
                        
    def calculate_battery_CAPEX(self, action_battery):
        
        five_kw_PRICE = 3000

        installation = 1000 * self.step_total_interest
        
        this_battery_CAPEX = five_kw_PRICE * self.step_battery_CAPEX
        
        battery_bos = this_battery_CAPEX * 0.5
        
        if self.previous_observation[19] == 0:
            battery_bos = this_battery_CAPEX * 0.5
        else:
            battery_bos = 0
        
        total_batery_cost = (this_battery_CAPEX +  battery_bos + installation) * action_battery
        
        return total_batery_cost
        
    def step(self, action):
        
        """
        defines actions, reward etc.
        """
        
        # RESET THE ANNUAL BALANCES
        self.total_CAPEX = 0
        self.pv_costs = 0
        self.fin_balance = 0
        self.number_installed = 0
        current_penalty = 0
        self.other_costs = 0
        battery_costs = 0
        next_step_penalty = 0
        self.step_total_interest = self.step_total_interest * self.normal_interest_rate
        current_operational_costs = self.operational_cost * self.step_total_interest
        
        #***
        self.step_battery_CAPEX = self.random_battery_CAPEX[abs(self.episode_len - 25)]
        
        self.cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
        self.import_price = self.random_import_price[abs(self.episode_len - 25)]
        self.efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
           
        self.panel_cost_and_inverter = self.calculate_panel_inv_cost(self.cost_per_Wp)
        FiT = self.calculate_FiT(self.episode_len, self.import_price)
        
        reward = 0   
        actions_step = np.random.rand(12)
        
        #  ***
        action_battery = action[1]
        action = action[0]
        
        # Find indices of the lowest 'action' values in previous_observation
        indices = np.argsort(self.previous_observation[:self.number_of_panels])[:action]

        # Replace these indices in the observation with efficiency_develop
        self.observation[:self.number_of_panels][indices] = self.efficency_develop

        # Copy over the other values from previous_observation to observation
        mask = np.ones(len(self.previous_observation[:self.number_of_panels]), dtype=bool)
        mask[indices] = False
        self.observation[:self.number_of_panels][mask] = self.previous_observation[:self.number_of_panels][mask]

        replaced_panels = np.zeros(len(self.previous_observation[:self.number_of_panels]), dtype=int)
        replaced_panels[indices] = 1

        instaltion = (self.observation[:self.number_of_panels] > 0).astype(int)
        self.pv_costs -= instaltion.sum() * current_operational_costs

        actions_step = np.array(replaced_panels)
        
        if action_battery == 1:           
            self.observation[31] = 1.
            self.battery_state = 1
            
        if action > 0:
            step_CAPEX, panel_cost_and_inverter = self.calculate_total_CAPEX(actions_step, self.panel_cost_and_inverter)
            self.pv_costs -= step_CAPEX
            
        else:
            panel_cost_and_inverter = 0
            
        battery_costs = self.calculate_battery_CAPEX(action_battery)
        
        self.pv_costs -= battery_costs

        
        next_observation = self._get_obs()

        # Calculate the Reslae value
        resale = self.calculate_resale(panel_cost_and_inverter, indices)
        
        self.pv_costs += resale
 
        
        # CALCULATE THE BUDGET INTEREST
        current_penalty, due_loans, next_step_penalty = self.calculate_penalty(self.episode_len, self.pv_costs)

        
        # CALCULATE THE ENERGY YIELD
        exported_revenue, AC_OUTPUT_tot, minimised_revenue = self.calculate_import_export(self.AC_OUTPUT, 
                                                                          self.elec_df, FiT, self.import_price)        
        
        pv_costs_observation = - self.pv_costs / 9000
        self.observation[self.number_of_panels + 4] = pv_costs_observation
        
        next_step_penalty_observation = - next_step_penalty / 7000
        self.observation[self.number_of_panels + 5] = next_step_penalty_observation
        
        
        # CALCULATE STEP BALANCES
        self.fin_balance += self.pv_costs
        self.fin_balance += current_penalty
        self.fin_balance += float(exported_revenue + minimised_revenue)
        
        # CALCULATE TOTAL BALANCES
        self.fin_balance_tot += self.fin_balance                
        
        # SUBSTRACT 1 FOR TIMESTEP
        self.episode_len -= 1
        done = self.episode_len <= 0
        
        #reward = self.fin_balance_tot / 1000 if done else 0
        reward = self.fin_balance / 1000
        
        # FAILURE
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)
        survival = self.failure(actions_step)
        
        for c, p in enumerate(survival):
            
            if c < self.number_of_panels:

                if p - 1 <= abs(self.episode_len - 24):
                    self.broke[c] = 1
                    self.observation[c] = 0
        
        # DEGRADATION RATE
        # Applying degradation only to panels that are operational (above 0.1 efficiency)
        active_panels = self.observation[:self.number_of_panels] > 0.1
        degradations = np.random.normal(self.deg_mu, self.deg_std, size=self.number_of_panels) / 100
        self.observation[:self.number_of_panels][active_panels] -= degradations[active_panels]
        
        # BATERY DEGRADATION
        if self.observation[31] > 0:
            self.battery_state -= 0.0145
            if self.battery_state < 0.8:
                self.battery_state = 0
        
        self.observation[31] = self.battery_state
        
        if not done: 
        
            self.next_cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
            self.next_import_price = self.random_import_price[abs(self.episode_len - 25)]
            self.next_efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
            next_FIT = self.calculate_FiT(self.episode_len, self.next_import_price)
        
            price_observation = (self.next_import_price - 0.00022499) / (0.0020798 - 0.00022499)
            self.observation[self.number_of_panels] = price_observation

            FiT_observation = (next_FIT - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
            self.observation[self.number_of_panels + 1] = FiT_observation

            eff_observation = (self.next_efficency_develop - 0.999) / (1.156 - 0.999)
            self.observation[self.number_of_panels + 2] = eff_observation

            cost_per_Wp_observation = (self.next_cost_per_Wp - 0.1712159) / (0.8214356 - 0.1712159) 
            self.observation[self.number_of_panels + 3] = cost_per_Wp_observation
            
            step_battery_CAPEX_obs = (self.step_battery_CAPEX - 0.03) / (4 - 0.03)
            self.observation[32] = step_battery_CAPEX_obs
        
        info = {"step financial balance (eur):": battery_costs,
               "total financial balance: (eur)": minimised_revenue,
               "internal rate of return": 0,
               "current_interest": resale,
                "net present value": 0}
         
        
        self.previous_observation = self.observation.copy()
        
        return self.observation, reward, done, False, info

# %%
class TestEnvironment(gym.Env):
    def __init__(self, AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_tariff, efficency, CAPEX, Battery_CAPEX):
        
        # Price per watthour
        self.import_price_df = import_tariff
        self.import_price_at_zero = np.float32(0.00035)
        self.import_price_rate = import_price_rate
        
        # Energy Balance
        self.AC_OUTPUT = AC_OUTPUT_arr
        self.elec_df = elec_consum_arr
        self.max_export = 4000
        self.number_of_panels = 24
        
        # Degradation
        self.deg_mu = 1.055
        self.deg_std = 0.555
        
        # Efficency Development
        self.efficency_develop_df = efficency
        self.efficency_at_zero = 1.0
        
        # Costs
        self.power_at_zero = 415
        self.cost_per_Wp_df_at_zero = 0.69
        self.cost_per_Wp_df = CAPEX
        self.initial_other_costs = 150
        
        self.operational_cost = 16.8
        #self.budget_constraint = 1500
        
        self.loan_interest_rate = 1.06
        self.normal_interest_rate = 1.02
        
        self.battery_CAPEX = Battery_CAPEX
        self.battery_CAPEX_at_zero = 1
            
        # Spaces and length
        self.action_space = spaces.MultiDiscrete([self.number_of_panels + 1, 2])
        self.observation_space = spaces.Box(0, 1.25, shape=(self.number_of_panels + 7 + 2,))
        self.episode_len = 25
        self.months_per_timestep = 12
        
    def _get_obs(self):
        
        return self.observation
    
    def calculate_import_export(self, AC_OUTPUT, elec_df, export_price, import_price):
        
        """
        Calculate the annual Wh of energy exported to the grid (exported) and saved (minimised)
        """
        
        batery_state = 1
        minimised_mult = 1
        export_mult = 1
        if self.battery_state > 0:
            minimised_mult = 2.175
            export_mult = 0.52
            batery_state = self.battery_state

        
        AC_OUTPUT_tot = self._get_obs()[0:self.number_of_panels].sum() * self.AC_OUTPUT 

        exported = (AC_OUTPUT_tot - self.elec_df).clip(min=0, max = self.max_export)        
        export_revenue = (export_price * exported).sum() * export_mult

        
        minimised = AC_OUTPUT_tot - exported 
        minimised_revenue = (minimised * (self.import_price_rate * import_price)).sum() * minimised_mult * batery_state
        

        return export_revenue, AC_OUTPUT_tot, minimised_revenue
    
    def reset(self, seed=None):
        
        """
        Reset the environment to the original state at t=1
        """
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)
            
        # Panels
        self.init_obs = np.random.uniform(0, 1, size=self.number_of_panels).astype(np.float32)
        self.init_obs = np.where(self.init_obs < 0.5, 0.0, np.random.uniform(0.85, 1.0, size=self.number_of_panels))

        # Combine all initialization into a single step for efficiency
        self.import_price_at_zero_norm = (self.import_price_at_zero - 0.00022499) / (0.0020798 - 0.00022499)
        self.FiT_at_zero_norm = (self.import_price_at_zero - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
        self.efficency_at_zero_norm = (self.efficency_at_zero - 0.999) / (1.156 - 0.999)
        self.panel_cost_and_inverter_at_zero_norm = (self.cost_per_Wp_df_at_zero - 0.1712159) / (0.8214356 - 0.1712159)
        
        self.current_budget_constraint = np.random.randint(0, 750)
        self.next_step_budget_constraint = 0
        
        
        self.battery_CAPEX_at_zero_norm = (self.battery_CAPEX_at_zero - 0.03) / (4 - 0.03)
        
        # Complete observation initialization in one go
        self.observation = np.concatenate([
            self.init_obs,
            [self.import_price_at_zero_norm, self.FiT_at_zero_norm, self.efficency_at_zero_norm, 
             self.panel_cost_and_inverter_at_zero_norm, 0., 0., 0., 0., self.battery_CAPEX_at_zero_norm]
        ]).astype(np.float32)

        self.previous_observation = self.observation.copy()

        # RANDOM IMPORT PRICE
        self.random_import_price = self.import_price_df[np.random.choice(self.import_price_df.shape[0])] 

        # RANDOM EFFICENCY
        self.random_efficency_develop = self.efficency_develop_df[np.random.choice(self.efficency_develop_df.shape[0])]   
        
        # RANDOM COST PER WP
        self.random_cost_per_Wp = self.cost_per_Wp_df[np.random.choice(self.cost_per_Wp_df.shape[0])]   
        
        self.random_battery_CAPEX = self.battery_CAPEX[np.random.choice(self.battery_CAPEX.shape[0])]
        
        self.episode_len = 25  
    
        info = {}
        
        # RESET BALANCES
        self.fin_balance_tot = 0
        self.reward_tot = 0
        self.env_balance_tot = 0
        self.produced = 0
        self.other_costs = 0
        self.FiT = 0.0004
        self.next_FiT = 0.0004
        self.resale_values = array_of_zeros = np.zeros(self.number_of_panels, dtype=np.float32)
        
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)
        self.total_cash_flow = []
        self.annual_cash_flow = 0
                
        self.due_loans = [0, 0, 0, 0] 
        self.current_interest = 0
        self.step_total_interest = 1
        
        self.two_year_ago_interest = 0
        self.first_year_interest = []
        self.second_year_interest = [0]
        self.third_year_interest = [0, 0]
        self.fourth_year_interest = [0, 0, 0]
        self.next_year_total = 0
        self.battery_state = 0

        self.survival = np.zeros(self.number_of_panels, dtype=np.float32)
    
        return self.observation, info
    
    def calculate_resale(self, initial_panel_cost, indices):
        
        self.resale_values[indices] = initial_panel_cost
        
        self.resale_values = self.resale_values * 0.85
        
        for count, i in enumerate(self.broke):
            if i == 1:
                self.resale_values[count] = 0
        
        resale_step = self.resale_values[indices].sum()
        
        return resale_step
    
    def calculate_panel_inv_cost(self, cost_per_Wp):
        
        PW_ep = self.efficency_develop * self.power_at_zero
        
        panel_cost_and_inverter = PW_ep * cost_per_Wp
        
        return panel_cost_and_inverter
    
    def calculate_irr_and_npv(self, pv_cost, minimised_revenue, export_revenue, penalty):
                
        """
        Calculates total cash flow of the project needed for the internal rate of return
        """ 
        self.expences = 0
        self.annual_cash_flow = 0
        initial_cost = 0
        
        self.expences = pv_cost
        self.annual_cash_flow = self.expences + export_revenue + minimised_revenue + penalty
        initial_cost_q, x = self.calculate_total_CAPEX(self.init_obs, self.panel_cost_and_inverter)
        initial_cost = - initial_cost_q
        
        if self.episode_len == 24:
            self.total_cash_flow.append(initial_cost + self.annual_cash_flow) 
        else:
            self.total_cash_flow.append(self.annual_cash_flow) 
        
        return self.total_cash_flow
        
    def calculate_penalty(self, current_step, annual_expense):
              
        year = 25 - current_step
        
        if year > 0:
            self.current_budget_constraint = self.next_step_budget_constraint    
            
        
        self.current_interest = self.next_year_total
        annual_expense = (-annual_expense)
        value = 0 
        loan = 0
        annual_interest = 0

        if annual_expense > self.current_budget_constraint:
            loan = (self.current_budget_constraint - annual_expense)
            value = annual_expense / self.current_budget_constraint
            periods = 2 if value < 2 else 3 if value < 3 else 4

            annual_interest = loan / periods
            interest_multiplier = 1

            for i in range(4):
                if i < periods:
                    self.due_loans[i] = annual_interest * interest_multiplier
                    interest_multiplier *= self.loan_interest_rate
                else:
                    self.due_loans[i] = 0
        else:
             self.due_loans = [0, 0, 0, 0]
    
        self.first_year_interest.append(self.due_loans[0])
        self.second_year_interest.append(self.due_loans[1])
        self.third_year_interest.append(self.due_loans[2])
        self.fourth_year_interest.append(self.due_loans[3])
    
    
        self.next_year_total = self.first_year_interest[year] + self.second_year_interest[year] + self.third_year_interest[year] + self.fourth_year_interest[year]
        
        self.next_step_budget_constraint = np.random.randint(0, 750) * self.step_total_interest
        current_budget_observation = (self.next_step_budget_constraint - 0 * self.step_total_interest) / (750 * self.step_total_interest - 0 * self.step_total_interest) 
        self.observation[self.number_of_panels + 6] = current_budget_observation
                
        return self.current_interest, self.due_loans, self.next_year_total
        
    def calculate_total_CAPEX(self, action_step, panel_cost_and_inverter):
        """
        Calculate CAPEX each step in a vectorized manner.
        """
        BOS = panel_cost_and_inverter * 0.55
        number_installed = int(np.sum(action_step))

        # Calculate costs from module and inverter
        panel_cost_and_inverter_step = panel_cost_and_inverter * number_installed

        # Calculate other installation costs
        if number_installed == 0:
            other_costs = 0
        elif number_installed == 1:
            other_costs = self.initial_other_costs * self.step_total_interest
        else:
            discounts = 0.9 ** np.arange(number_installed)
            other_costs = (self.initial_other_costs * self.step_total_interest * discounts).sum()

        # Calculate BOS costs using vector operations
        is_new_installation = (self.previous_observation[:number_installed] == 0) & (action_step[:number_installed] == 1)
        is_replacement = (self.previous_observation[:number_installed] > 0) & (action_step[:number_installed] == 1)
        BOS_cost = np.sum(BOS * is_new_installation) + np.sum((BOS / 2) * is_replacement)

        # Sum total CAPEX
        total_CAPEX = panel_cost_and_inverter_step + BOS_cost + other_costs

        return total_CAPEX, panel_cost_and_inverter
        
    def failure(self, actions):
        
        beta = 3  # Shape parameter
        phi = 50  # Scale parameter  

        # Determine which panels are active based on the actions and previous observations.
        if self.episode_len == 24:
            active_panels = (self.observation[:self.number_of_panels] > 0.85)
        else:
            active_panels = (self.observation[:self.number_of_panels] == self.efficency_develop)

        # Calculate lifespan for all active panels at once
        lifespans = np.random.weibull(beta, self.number_of_panels) * phi
        lifespans = np.where(active_panels, lifespans, 0)  # Apply lifespan only to active panels

        # Adjust survival times based on episode length
        self.survival[:self.number_of_panels] = np.where(
            active_panels,
            np.abs(lifespans.astype(int)) + np.abs(self.episode_len - 25),
            self.survival[:self.number_of_panels]
        )

        return self.survival

    def calculate_FiT(self, episodes, import_price):
            
        self.FiT = import_price
            
        if episodes == 25:
            self.FiT = self.FiT
            
        elif episodes == 24 or episodes == 23:
            self.FiT = self.FiT * 0.64
            
        elif episodes == 22:
            self.FiT = self.FiT * 0.46
            
        elif episodes == 21:
            self.FiT = self.FiT * 0.55
            
        elif episodes < 20:
            self.FiT = self.FiT * 0.33
            
        elif episodes == 20:
            self.FiT = self.FiT * 0.37
            
        return self.FiT
    
    def calculate_battery_CAPEX(self, action_battery):
        
        five_kw_PRICE = 3000

        installation = 1000 * self.step_total_interest
        
        this_battery_CAPEX = five_kw_PRICE * self.step_battery_CAPEX
        
        battery_bos = this_battery_CAPEX * 0.5
        
        if self.previous_observation[19] == 0:
            battery_bos = this_battery_CAPEX * 0.5
        else:
            battery_bos = 0
        
        total_batery_cost = (this_battery_CAPEX +  battery_bos + installation) * action_battery
        
        return total_batery_cost
                  
    def step(self, action):
        
        """
        defines actions, reward etc.
        """
        
        # RESET THE ANNUAL BALANCES
        self.total_CAPEX = 0
        self.pv_costs = 0
        self.fin_balance = 0
        self.number_installed = 0
        irr_fin = 0
        npv_fin = 0
        battery_costs = 0
        current_penalty = 0
        self.other_costs = 0
        next_step_penalty = 0
        self.step_total_interest = self.step_total_interest * self.normal_interest_rate
        current_operational_costs = self.operational_cost * self.step_total_interest
        self.step_battery_CAPEX = self.random_battery_CAPEX[abs(self.episode_len - 25)]

        
        self.cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
        self.import_price = self.random_import_price[abs(self.episode_len - 25)]
        self.efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
           
        self.panel_cost_and_inverter = self.calculate_panel_inv_cost(self.cost_per_Wp)
        FiT = self.calculate_FiT(self.episode_len, self.import_price)
        
        reward = 0   
        actions_step = np.random.rand(self.number_of_panels + 1)
        
        
        action_battery = action[1]
        action = action[0]
        
        # Find indices of the lowest 'action' values in previous_observation
        indices = np.argsort(self.previous_observation[:self.number_of_panels])[:action]

        # Replace these indices in the observation with efficiency_develop
        self.observation[:self.number_of_panels][indices] = self.efficency_develop

        # Copy over the other values from previous_observation to observation
        mask = np.ones(len(self.previous_observation[:self.number_of_panels]), dtype=bool)
        mask[indices] = False
        self.observation[:self.number_of_panels][mask] = self.previous_observation[:self.number_of_panels][mask]

        replaced_panels = np.zeros(len(self.previous_observation[:self.number_of_panels]), dtype=int)
        replaced_panels[indices] = 1

        instaltion = (self.observation[:self.number_of_panels] > 0).astype(int)
        self.pv_costs -= instaltion.sum() * current_operational_costs

        actions_step = np.array(replaced_panels)
        
        if action_battery == 1:           
            self.observation[31] = 1.
            self.battery_state = 1
            
        if action > 0:
            step_CAPEX, panel_cost_and_inverter = self.calculate_total_CAPEX(actions_step, self.panel_cost_and_inverter)
            self.pv_costs -= step_CAPEX
            
        else:
            panel_cost_and_inverter = 0
            
        battery_costs = self.calculate_battery_CAPEX(action_battery)
        
        self.pv_costs -= battery_costs
        next_observation = self._get_obs()

        # Calculate the Reslae value
        resale = self.calculate_resale(panel_cost_and_inverter, indices) #  ***
        
        self.pv_costs += resale

        
        # CALCULATE THE BUDGET INTEREST
        current_penalty, due_loans, next_step_penalty = self.calculate_penalty(self.episode_len, self.pv_costs)
        
        
        # CALCULATE THE ENERGY YIELD
        exported_revenue, AC_OUTPUT_tot, minimised_revenue = self.calculate_import_export(self.AC_OUTPUT, 
                                                                          self.elec_df, FiT, self.import_price)        
        
        pv_costs_observation = - self.pv_costs / 9000
        self.observation[self.number_of_panels + 4] = pv_costs_observation
        
        next_step_penalty_observation = - next_step_penalty / 7000
        self.observation[self.number_of_panels + 5] = next_step_penalty_observation
        
        
        # CALCULATE STEP BALANCES
        self.fin_balance += self.pv_costs
        self.fin_balance += current_penalty
        self.fin_balance += float(exported_revenue + minimised_revenue)
        
        # CALCULATE TOTAL BALANCES
        self.fin_balance_tot += self.fin_balance                
        
        # SUBSTRACT 1 FOR TIMESTEP
        self.episode_len -= 1
        done = self.episode_len <= 0
        
        # CALCULATE IRR, NPV AND CARBON INTENSITY
        total_cash_flow = self.calculate_irr_and_npv(self.pv_costs, exported_revenue, minimised_revenue, current_penalty)
        irr = npf.irr(total_cash_flow) * 100
        npv = npf.npv(0.04 ,total_cash_flow)
            
        # RETURNS AND CALCULATE REWARD
        if self.episode_len == 0:
            irr_fin = irr
            npv_fin = npv

        reward = self.fin_balance_tot / 1000 if done else 0
        
        # FAILURE
         
        survival = self.failure(actions_step)
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)

        for c, p in enumerate(survival):
            
            if c < self.number_of_panels:

                if p - 1 <= abs(self.episode_len - 24):
                    self.broke[c] = 1

                    self.observation[c] = 0
        
        # DEGRADATION RATE
        # Applying degradation only to panels that are operational (above 0.1 efficiency)
        active_panels = self.observation[:self.number_of_panels] > 0.1
        degradations = np.random.normal(self.deg_mu, self.deg_std, size=self.number_of_panels) / 100
        self.observation[:self.number_of_panels][active_panels] -= degradations[active_panels]
        
        # BATERY DEGRADATION
        if self.observation[31] > 0:
            self.battery_state -= 0.0145
            if self.battery_state < 0.8:
                self.battery_state = 0
        
        self.observation[31] = self.battery_state

        
        if not done: 
        
            self.next_cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
            self.next_import_price = self.random_import_price[abs(self.episode_len - 25)]
            self.next_efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
            next_FIT = self.calculate_FiT(self.episode_len, self.next_import_price)
        
            price_observation = (self.next_import_price - 0.00022499) / (0.0020798 - 0.00022499)
            self.observation[self.number_of_panels] = price_observation

            FiT_observation = (next_FIT - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
            self.observation[self.number_of_panels + 1] = FiT_observation

            eff_observation = (self.next_efficency_develop - 0.999) / (1.156 - 0.999)
            self.observation[self.number_of_panels + 2] = eff_observation

            cost_per_Wp_observation = (self.next_cost_per_Wp - 0.1712159) / (0.8214356 - 0.1712159) 
            self.observation[self.number_of_panels + 3] = cost_per_Wp_observation
            
            step_battery_CAPEX_obs = (self.step_battery_CAPEX - 0.03) / (4 - 0.03)
            self.observation[32] = step_battery_CAPEX_obs
        
        info = {"step financial balance (eur):": self.fin_balance,
               "total financial balance: (eur)": self.fin_balance_tot,
               "internal rate of return": irr_fin,
               "current_interest": current_penalty,
                "net present value": npv_fin}
         
        
        self.previous_observation = self.observation.copy()
        
        return self.observation, reward, done, False, info

# %%
env = TrainEnvironment(AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_price_train_arr, Eff_train_arr, CAPEX_JA_train_arr, Battery_CAPEX_train_arr)
env_test = TestEnvironment(AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_price_test_arr, Eff_test_arr, CAPEX_JA_test_arr, Battery_CAPEX_test_arr)

# %%
def make_env(rank: int, seed: int = 0) -> Callable:
    def _init() -> gym.Env:
        random.seed(seed + rank)
        np.random.seed(seed + rank) 
        env = TrainEnvironment(AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_price_train_arr, Eff_train_arr, CAPEX_JA_train_arr, Battery_CAPEX_train_arr)
        env.reset(seed=seed + rank)
        return env

    return _init
# Number of environments to run in parallel
num_cpu = 16
env = SubprocVecEnv([make_env(i) for i in range(num_cpu)])

# %%
log_path = "./logs/"
eval_callback = EvalCallback(env_test, best_model_save_path = "C:/Users/kubaw/Desktop/DELFT/THESIS/CODE/TEST_MODELS/bateryMAX24_low/",
                             log_path = log_path, n_eval_episodes = 750, eval_freq=10000,
                             deterministic=True, render=False)


policy_kwargs = dict(net_arch=dict(pi=[1024, 1024], vf=[1024, 1024]))

# %%
model = PPO("MlpPolicy", env, learning_rate = learning_rate, batch_size = 1024, n_epochs = 24,  policy_kwargs = policy_kwargs, gamma = 0.99,  verbose=1, tensorboard_log = "C:/Users/kubaw/Desktop/DELFT/THESIS\CODE/TEST_MODELS/LOGS/logs")
TIMESTEPS = 5000000
model.learn(total_timesteps = TIMESTEPS, callback=eval_callback)
# Out:
# Using cpu device
# Logging to C:/Users/kubaw/Desktop/DELFT/THESIS\CODE/TEST_MODELS/LOGS/logs\PPO_396
# C:\Users\kubaw\miniforge3\envs\pytorch-env\lib\site-packages\stable_baselines3\common\callbacks.py:414: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x000002A0A8BABAF0> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x000002A08C03C7C0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ------------------------------
# | time/              |       |
# |    fps             | 3115  |
# |    iterations      | 1     |
# |    time_elapsed    | 10    |
# |    total_timesteps | 32768 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1225        |
# |    iterations           | 2           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.014258133 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.000881    |
# |    learning_rate        | 0.000298    |
# |    loss                 | 511         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 1.05e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1012        |
# |    iterations           | 3           |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009871824 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | -8.34e-06   |
# |    learning_rate        | 0.000296    |
# |    loss                 | 676         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.0096     |
# |    value_loss           | 1.32e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 940        |
# |    iterations           | 4          |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.01488437 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.83      |
# |    explained_variance   | -2.38e-06  |
# |    learning_rate        | 0.000294   |
# |    loss                 | 635        |
# |    n_updates            | 72         |
# |    policy_gradient_loss | -0.0124    |
# |    value_loss           | 1.31e+03   |
# ----------------------------------------
# C:\Users\kubaw\miniforge3\envs\pytorch-env\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# C:\Users\kubaw\AppData\Local\Temp\ipykernel_10116\1914628558.py:213: RuntimeWarning: divide by zero encountered in scalar divide
#   value = annual_expense / self.current_budget_constraint
# Eval num_timesteps=160000, episode_reward=14.92 +/- 12.57
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 14.9        |
# | time/                   |             |
# |    total_timesteps      | 160000      |
# | train/                  |             |
# |    approx_kl            | 0.014524533 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | -1.67e-06   |
# |    learning_rate        | 0.000292    |
# |    loss                 | 547         |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 1.08e+03    |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 800    |
# |    iterations      | 5      |
# |    time_elapsed    | 204    |
# |    total_timesteps | 163840 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 6           |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.017098049 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | -1.67e-06   |
# |    learning_rate        | 0.00029     |
# |    loss                 | 402         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 825         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 7           |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.014867535 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.000289    |
# |    loss                 | 366         |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 735         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 8           |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.017199606 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.000287    |
# |    loss                 | 272         |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 565         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 9           |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.018649016 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.000285    |
# |    loss                 | 198         |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 416         |
# -----------------------------------------
# Eval num_timesteps=320000, episode_reward=24.59 +/- 13.46
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 24.6        |
# | time/                   |             |
# |    total_timesteps      | 320000      |
# | train/                  |             |
# |    approx_kl            | 0.021197893 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.000283    |
# |    loss                 | 143         |
# |    n_updates            | 216         |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 306         |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 747    |
# |    iterations      | 10     |
# |    time_elapsed    | 438    |
# |    total_timesteps | 327680 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 11          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.023096176 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.000281    |
# |    loss                 | 114         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 233         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 12          |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.025608376 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.000279    |
# |    loss                 | 87.4        |
# |    n_updates            | 264         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 173         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 13          |
# |    time_elapsed         | 567         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.020125017 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.000277    |
# |    loss                 | 70.8        |
# |    n_updates            | 288         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 140         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 752        |
# |    iterations           | 14         |
# |    time_elapsed         | 609        |
# |    total_timesteps      | 458752     |
# | train/                  |            |
# |    approx_kl            | 0.02722843 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.69      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.000275   |
# |    loss                 | 74         |
# |    n_updates            | 312        |
# |    policy_gradient_loss | -0.0129    |
# |    value_loss           | 144        |
# ----------------------------------------
# Eval num_timesteps=480000, episode_reward=27.76 +/- 14.41
# Episode length: 25.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 25         |
# |    mean_reward          | 27.8       |
# | time/                   |            |
# |    total_timesteps      | 480000     |
# | train/                  |            |
# |    approx_kl            | 0.02040311 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.61      |
# |    explained_variance   | 7.15e-07   |
# |    learning_rate        | 0.000273   |
# |    loss                 | 62.1       |
# |    n_updates            | 336        |
# |    policy_gradient_loss | -0.0134    |
# |    value_loss           | 129        |
# ----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 729    |
# |    iterations      | 15     |
# |    time_elapsed    | 673    |
# |    total_timesteps | 491520 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 16          |
# |    time_elapsed         | 716         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.019862989 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.000271    |
# |    loss                 | 64.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 126         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 17          |
# |    time_elapsed         | 758         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.015624924 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 5.36e-07    |
# |    learning_rate        | 0.00027     |
# |    loss                 | 64.2        |
# |    n_updates            | 384         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 18          |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.013101477 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.00295     |
# |    learning_rate        | 0.000268    |
# |    loss                 | 59          |
# |    n_updates            | 408         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 130         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 738        |
# |    iterations           | 19         |
# |    time_elapsed         | 843        |
# |    total_timesteps      | 622592     |
# | train/                  |            |
# |    approx_kl            | 0.01273716 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.21      |
# |    explained_variance   | 0.0935     |
# |    learning_rate        | 0.000266   |
# |    loss                 | 47.4       |
# |    n_updates            | 432        |
# |    policy_gradient_loss | -0.0134    |
# |    value_loss           | 110        |
# ----------------------------------------
# Eval num_timesteps=640000, episode_reward=38.23 +/- 19.45
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 38.2        |
# | time/                   |             |
# |    total_timesteps      | 640000      |
# | train/                  |             |
# |    approx_kl            | 0.010598933 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.000264    |
# |    loss                 | 50          |
# |    n_updates            | 456         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 111         |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 721    |
# |    iterations      | 20     |
# |    time_elapsed    | 908    |
# |    total_timesteps | 655360 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 21          |
# |    time_elapsed         | 951         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.009604612 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.000262    |
# |    loss                 | 54.5        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 22          |
# |    time_elapsed         | 994         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.010549966 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.00026     |
# |    loss                 | 51.1        |
# |    n_updates            | 504         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 113         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 23           |
# |    time_elapsed         | 1036         |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0101203155 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.81        |
# |    explained_variance   | 0.465        |
# |    learning_rate        | 0.000258     |
# |    loss                 | 56.8         |
# |    n_updates            | 528          |
# |    policy_gradient_loss | -0.00821     |
# |    value_loss           | 115          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 24          |
# |    time_elapsed         | 1079        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.008725997 |
# |    clip_fraction        | 0.0989      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.000256    |
# |    loss                 | 59.9        |
# |    n_updates            | 552         |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 115         |
# -----------------------------------------
# Eval num_timesteps=800000, episode_reward=39.09 +/- 19.38
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 39.1        |
# | time/                   |             |
# |    total_timesteps      | 800000      |
# | train/                  |             |
# |    approx_kl            | 0.007736757 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.000254    |
# |    loss                 | 57.7        |
# |    n_updates            | 576         |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 107         |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 716    |
# |    iterations      | 25     |
# |    time_elapsed    | 1144   |
# |    total_timesteps | 819200 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 26          |
# |    time_elapsed         | 1186        |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.006266716 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.000252    |
# |    loss                 | 51.7        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00537    |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 27          |
# |    time_elapsed         | 1229        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.005481704 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.000251    |
# |    loss                 | 49.1        |
# |    n_updates            | 624         |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 28           |
# |    time_elapsed         | 1270         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0074393703 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.57        |
# |    explained_variance   | 0.565        |
# |    learning_rate        | 0.000249     |
# |    loss                 | 48.2         |
# |    n_updates            | 648          |
# |    policy_gradient_loss | -0.00435     |
# |    value_loss           | 98           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 29          |
# |    time_elapsed         | 1314        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.007267369 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.000247    |
# |    loss                 | 44.2        |
# |    n_updates            | 672         |
# |    policy_gradient_loss | -0.00414    |
# |    value_loss           | 100         |
# -----------------------------------------
# Eval num_timesteps=960000, episode_reward=38.93 +/- 17.83
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 38.9        |
# | time/                   |             |
# |    total_timesteps      | 960000      |
# | train/                  |             |
# |    approx_kl            | 0.010863528 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.000245    |
# |    loss                 | 45.1        |
# |    n_updates            | 696         |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 98.9        |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 712    |
# |    iterations      | 30     |
# |    time_elapsed    | 1378   |
# |    total_timesteps | 983040 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 31          |
# |    time_elapsed         | 1421        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.009156198 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.000243    |
# |    loss                 | 47.4        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 90.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 32           |
# |    time_elapsed         | 1464         |
# |    total_timesteps      | 1048576      |
# | train/                  |              |
# |    approx_kl            | 0.0066816937 |
# |    clip_fraction        | 0.0643       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.000241     |
# |    loss                 | 45.1         |
# |    n_updates            | 744          |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 89.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 33           |
# |    time_elapsed         | 1506         |
# |    total_timesteps      | 1081344      |
# | train/                  |              |
# |    approx_kl            | 0.0064652544 |
# |    clip_fraction        | 0.055        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.000239     |
# |    loss                 | 52.3         |
# |    n_updates            | 768          |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 98.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 34          |
# |    time_elapsed         | 1549        |
# |    total_timesteps      | 1114112     |
# | train/                  |             |
# |    approx_kl            | 0.004970609 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.000237    |
# |    loss                 | 49          |
# |    n_updates            | 792         |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 95.2        |
# -----------------------------------------
# Eval num_timesteps=1120000, episode_reward=40.76 +/- 19.20
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 40.8         |
# | time/                   |              |
# |    total_timesteps      | 1120000      |
# | train/                  |              |
# |    approx_kl            | 0.0059097987 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.576        |
# |    learning_rate        | 0.000235     |
# |    loss                 | 57           |
# |    n_updates            | 816          |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 102          |
# ------------------------------------------
# New best mean reward!
# --------------------------------
# | time/              |         |
# |    fps             | 710     |
# |    iterations      | 35      |
# |    time_elapsed    | 1614    |
# |    total_timesteps | 1146880 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 711          |
# |    iterations           | 36           |
# |    time_elapsed         | 1657         |
# |    total_timesteps      | 1179648      |
# | train/                  |              |
# |    approx_kl            | 0.0045647305 |
# |    clip_fraction        | 0.0553       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.592        |
# |    learning_rate        | 0.000233     |
# |    loss                 | 50.1         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 99.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 37          |
# |    time_elapsed         | 1700        |
# |    total_timesteps      | 1212416     |
# | train/                  |             |
# |    approx_kl            | 0.006183204 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.000232    |
# |    loss                 | 55          |
# |    n_updates            | 864         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 97.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 38           |
# |    time_elapsed         | 1742         |
# |    total_timesteps      | 1245184      |
# | train/                  |              |
# |    approx_kl            | 0.0064186743 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.00023      |
# |    loss                 | 46.1         |
# |    n_updates            | 888          |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 94.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 39           |
# |    time_elapsed         | 1785         |
# |    total_timesteps      | 1277952      |
# | train/                  |              |
# |    approx_kl            | 0.0069721956 |
# |    clip_fraction        | 0.0569       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.599        |
# |    learning_rate        | 0.000228     |
# |    loss                 | 52.1         |
# |    n_updates            | 912          |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 96.2         |
# ------------------------------------------
# Eval num_timesteps=1280000, episode_reward=42.93 +/- 20.41
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 42.9         |
# | time/                   |              |
# |    total_timesteps      | 1280000      |
# | train/                  |              |
# |    approx_kl            | 0.0067958077 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.596        |
# |    learning_rate        | 0.000226     |
# |    loss                 | 46.2         |
# |    n_updates            | 936          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 96.3         |
# ------------------------------------------
# New best mean reward!
# --------------------------------
# | time/              |         |
# |    fps             | 708     |
# |    iterations      | 40      |
# |    time_elapsed    | 1850    |
# |    total_timesteps | 1310720 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 41          |
# |    time_elapsed         | 1893        |
# |    total_timesteps      | 1343488     |
# | train/                  |             |
# |    approx_kl            | 0.005053882 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.000224    |
# |    loss                 | 51          |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 102         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 42           |
# |    time_elapsed         | 1936         |
# |    total_timesteps      | 1376256      |
# | train/                  |              |
# |    approx_kl            | 0.0060496614 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.616        |
# |    learning_rate        | 0.000222     |
# |    loss                 | 47.1         |
# |    n_updates            | 984          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 94.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 712          |
# |    iterations           | 43           |
# |    time_elapsed         | 1978         |
# |    total_timesteps      | 1409024      |
# | train/                  |              |
# |    approx_kl            | 0.0053344686 |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.605        |
# |    learning_rate        | 0.00022      |
# |    loss                 | 55           |
# |    n_updates            | 1008         |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 107          |
# ------------------------------------------
# Eval num_timesteps=1440000, episode_reward=42.60 +/- 19.66
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 42.6        |
# | time/                   |             |
# |    total_timesteps      | 1440000     |
# | train/                  |             |
# |    approx_kl            | 0.006037496 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.000218    |
# |    loss                 | 49.8        |
# |    n_updates            | 1032        |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 103         |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 705     |
# |    iterations      | 44      |
# |    time_elapsed    | 2044    |
# |    total_timesteps | 1441792 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 45          |
# |    time_elapsed         | 2086        |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.004853409 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.000216    |
# |    loss                 | 49.5        |
# |    n_updates            | 1056        |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 97          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 46           |
# |    time_elapsed         | 2130         |
# |    total_timesteps      | 1507328      |
# | train/                  |              |
# |    approx_kl            | 0.0072885314 |
# |    clip_fraction        | 0.0543       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.612        |
# |    learning_rate        | 0.000214     |
# |    loss                 | 46.3         |
# |    n_updates            | 1080         |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 95           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 47          |
# |    time_elapsed         | 2173        |
# |    total_timesteps      | 1540096     |
# | train/                  |             |
# |    approx_kl            | 0.009954748 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.000213    |
# |    loss                 | 44.2        |
# |    n_updates            | 1104        |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 90.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 48           |
# |    time_elapsed         | 2215         |
# |    total_timesteps      | 1572864      |
# | train/                  |              |
# |    approx_kl            | 0.0049435524 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.622        |
# |    learning_rate        | 0.000211     |
# |    loss                 | 43.6         |
# |    n_updates            | 1128         |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 93.2         |
# ------------------------------------------
# Eval num_timesteps=1600000, episode_reward=41.80 +/- 19.52
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 41.8         |
# | time/                   |              |
# |    total_timesteps      | 1600000      |
# | train/                  |              |
# |    approx_kl            | 0.0039014218 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.622        |
# |    learning_rate        | 0.000209     |
# |    loss                 | 45.3         |
# |    n_updates            | 1152         |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 91.3         |
# ------------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 704     |
# |    iterations      | 49      |
# |    time_elapsed    | 2280    |
# |    total_timesteps | 1605632 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 50           |
# |    time_elapsed         | 2323         |
# |    total_timesteps      | 1638400      |
# | train/                  |              |
# |    approx_kl            | 0.0046102954 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 0.000207     |
# |    loss                 | 46.2         |
# |    n_updates            | 1176         |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 94.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 51          |
# |    time_elapsed         | 2365        |
# |    total_timesteps      | 1671168     |
# | train/                  |             |
# |    approx_kl            | 0.005900279 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.000205    |
# |    loss                 | 48          |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 94.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 52           |
# |    time_elapsed         | 2409         |
# |    total_timesteps      | 1703936      |
# | train/                  |              |
# |    approx_kl            | 0.0051027783 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.614        |
# |    learning_rate        | 0.000203     |
# |    loss                 | 45.2         |
# |    n_updates            | 1224         |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 96.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 708          |
# |    iterations           | 53           |
# |    time_elapsed         | 2451         |
# |    total_timesteps      | 1736704      |
# | train/                  |              |
# |    approx_kl            | 0.0058281077 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 0.000201     |
# |    loss                 | 44           |
# |    n_updates            | 1248         |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 95           |
# ------------------------------------------
# Eval num_timesteps=1760000, episode_reward=41.51 +/- 19.51
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 41.5        |
# | time/                   |             |
# |    total_timesteps      | 1760000     |
# | train/                  |             |
# |    approx_kl            | 0.008822107 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.000199    |
# |    loss                 | 47.5        |
# |    n_updates            | 1272        |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 93.3        |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 703     |
# |    iterations      | 54      |
# |    time_elapsed    | 2515    |
# |    total_timesteps | 1769472 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 55           |
# |    time_elapsed         | 2557         |
# |    total_timesteps      | 1802240      |
# | train/                  |              |
# |    approx_kl            | 0.0071241427 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.621        |
# |    learning_rate        | 0.000197     |
# |    loss                 | 40           |
# |    n_updates            | 1296         |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 87.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 56          |
# |    time_elapsed         | 2600        |
# |    total_timesteps      | 1835008     |
# | train/                  |             |
# |    approx_kl            | 0.005777483 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.000195    |
# |    loss                 | 42.9        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 84.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 57         |
# |    time_elapsed         | 2642       |
# |    total_timesteps      | 1867776    |
# | train/                  |            |
# |    approx_kl            | 0.01942372 |
# |    clip_fraction        | 0.067      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.621      |
# |    learning_rate        | 0.000194   |
# |    loss                 | 42         |
# |    n_updates            | 1344       |
# |    policy_gradient_loss | -0.00104   |
# |    value_loss           | 89.6       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 58           |
# |    time_elapsed         | 2686         |
# |    total_timesteps      | 1900544      |
# | train/                  |              |
# |    approx_kl            | 0.0035903878 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# ...
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 135          |
# |    time_elapsed         | 6317         |
# |    total_timesteps      | 4423680      |
# | train/                  |              |
# |    approx_kl            | 0.0024945964 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.657       |
# |    explained_variance   | 0.645        |
# |    learning_rate        | 4.53e-05     |
# |    loss                 | 46           |
# |    n_updates            | 3216         |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 88.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 136          |
# |    time_elapsed         | 6359         |
# |    total_timesteps      | 4456448      |
# | train/                  |              |
# |    approx_kl            | 0.0017663201 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.649       |
# |    explained_variance   | 0.633        |
# |    learning_rate        | 4.34e-05     |
# |    loss                 | 41.4         |
# |    n_updates            | 3240         |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 86.2         |
# ------------------------------------------
# Eval num_timesteps=4480000, episode_reward=40.09 +/- 18.40
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 40.1         |
# | time/                   |              |
# |    total_timesteps      | 4480000      |
# | train/                  |              |
# |    approx_kl            | 0.0020115809 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.631       |
# |    explained_variance   | 0.631        |
# |    learning_rate        | 4.15e-05     |
# |    loss                 | 44.4         |
# |    n_updates            | 3264         |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 91.3         |
# ------------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 698     |
# |    iterations      | 137     |
# |    time_elapsed    | 6424    |
# |    total_timesteps | 4489216 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 138          |
# |    time_elapsed         | 6467         |
# |    total_timesteps      | 4521984      |
# | train/                  |              |
# |    approx_kl            | 0.0017651583 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.626       |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 3.96e-05     |
# |    loss                 | 46.4         |
# |    n_updates            | 3288         |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 88           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 139          |
# |    time_elapsed         | 6511         |
# |    total_timesteps      | 4554752      |
# | train/                  |              |
# |    approx_kl            | 0.0016000087 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.63        |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 3.77e-05     |
# |    loss                 | 43.7         |
# |    n_updates            | 3312         |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 88.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 140          |
# |    time_elapsed         | 6553         |
# |    total_timesteps      | 4587520      |
# | train/                  |              |
# |    approx_kl            | 0.0018413558 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 3.58e-05     |
# |    loss                 | 47.7         |
# |    n_updates            | 3336         |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 93.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 141          |
# |    time_elapsed         | 6596         |
# |    total_timesteps      | 4620288      |
# | train/                  |              |
# |    approx_kl            | 0.0020238264 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.631        |
# |    learning_rate        | 3.39e-05     |
# |    loss                 | 46           |
# |    n_updates            | 3360         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 91           |
# ------------------------------------------
# Eval num_timesteps=4640000, episode_reward=42.02 +/- 18.77
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 42           |
# | time/                   |              |
# |    total_timesteps      | 4640000      |
# | train/                  |              |
# |    approx_kl            | 0.0019316928 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.591       |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 3.2e-05      |
# |    loss                 | 39.3         |
# |    n_updates            | 3384         |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 79.4         |
# ------------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 698     |
# |    iterations      | 142     |
# |    time_elapsed    | 6663    |
# |    total_timesteps | 4653056 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 698          |
# |    iterations           | 143          |
# |    time_elapsed         | 6706         |
# |    total_timesteps      | 4685824      |
# | train/                  |              |
# |    approx_kl            | 0.0010840106 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.592       |
# |    explained_variance   | 0.618        |
# |    learning_rate        | 3.01e-05     |
# |    loss                 | 46.2         |
# |    n_updates            | 3408         |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 87.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 144          |
# |    time_elapsed         | 6749         |
# |    total_timesteps      | 4718592      |
# | train/                  |              |
# |    approx_kl            | 0.0015072755 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 2.82e-05     |
# |    loss                 | 40.6         |
# |    n_updates            | 3432         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 82.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 145          |
# |    time_elapsed         | 6791         |
# |    total_timesteps      | 4751360      |
# | train/                  |              |
# |    approx_kl            | 0.0019089599 |
# |    clip_fraction        | 0.00996      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 2.63e-05     |
# |    loss                 | 44.1         |
# |    n_updates            | 3456         |
# |    policy_gradient_loss | -0.000878    |
# |    value_loss           | 83.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 146          |
# |    time_elapsed         | 6835         |
# |    total_timesteps      | 4784128      |
# | train/                  |              |
# |    approx_kl            | 0.0016294512 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.639        |
# |    learning_rate        | 2.44e-05     |
# |    loss                 | 37.2         |
# |    n_updates            | 3480         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 85.9         |
# ------------------------------------------
# Eval num_timesteps=4800000, episode_reward=43.32 +/- 20.35
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 43.3         |
# | time/                   |              |
# |    total_timesteps      | 4800000      |
# | train/                  |              |
# |    approx_kl            | 0.0009419644 |
# |    clip_fraction        | 0.0096       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.565       |
# |    explained_variance   | 0.637        |
# |    learning_rate        | 2.25e-05     |
# |    loss                 | 38.8         |
# |    n_updates            | 3504         |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 86.5         |
# ------------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 698     |
# |    iterations      | 147     |
# |    time_elapsed    | 6900    |
# |    total_timesteps | 4816896 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 698          |
# |    iterations           | 148          |
# |    time_elapsed         | 6943         |
# |    total_timesteps      | 4849664      |
# | train/                  |              |
# |    approx_kl            | 0.0015155224 |
# |    clip_fraction        | 0.00963      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.558       |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 2.06e-05     |
# |    loss                 | 40.5         |
# |    n_updates            | 3528         |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 82.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 698          |
# |    iterations           | 149          |
# |    time_elapsed         | 6986         |
# |    total_timesteps      | 4882432      |
# | train/                  |              |
# |    approx_kl            | 0.0015764353 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 0.645        |
# |    learning_rate        | 1.87e-05     |
# |    loss                 | 44.7         |
# |    n_updates            | 3552         |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 87.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 150          |
# |    time_elapsed         | 7028         |
# |    total_timesteps      | 4915200      |
# | train/                  |              |
# |    approx_kl            | 0.0015382945 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.648        |
# |    learning_rate        | 1.68e-05     |
# |    loss                 | 41.8         |
# |    n_updates            | 3576         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 85.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 151          |
# |    time_elapsed         | 7071         |
# |    total_timesteps      | 4947968      |
# | train/                  |              |
# |    approx_kl            | 0.0011736348 |
# |    clip_fraction        | 0.0079       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.651        |
# |    learning_rate        | 1.49e-05     |
# |    loss                 | 44.3         |
# |    n_updates            | 3600         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 86.4         |
# ------------------------------------------
# Eval num_timesteps=4960000, episode_reward=41.14 +/- 20.21
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 41.1        |
# | time/                   |             |
# |    total_timesteps      | 4960000     |
# | train/                  |             |
# |    approx_kl            | 0.001588416 |
# |    clip_fraction        | 0.00979     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.566      |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 1.3e-05     |
# |    loss                 | 43.3        |
# |    n_updates            | 3624        |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 87.8        |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 697     |
# |    iterations      | 152     |
# |    time_elapsed    | 7136    |
# |    total_timesteps | 4980736 |
# --------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 698          |
# |    iterations           | 153          |
# |    time_elapsed         | 7178         |
# |    total_timesteps      | 5013504      |
# | train/                  |              |
# |    approx_kl            | 0.0014331158 |
# |    clip_fraction        | 0.00839      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 1.11e-05     |
# |    loss                 | 44.9         |
# |    n_updates            | 3648         |
# |    policy_gradient_loss | -0.000936    |
# |    value_loss           | 86           |
# ------------------------------------------

# %%
model.save(r"C:\Users\kubaw\Desktop\DELFT\THESIS\CODE\TEST_MODELS\bateryMAX24_low")

# %%
model = PPO.load(r"C:\Users\kubaw\Desktop\DELFT\THESIS\CODE\TEST_MODELS\bateryMAX24_low.zip")

# %%
evaluate2(10000, env_test, model)
# Out:
# C:\Users\kubaw\AppData\Local\Temp\ipykernel_10116\1914628558.py:213: RuntimeWarning: divide by zero encountered in scalar divide
#   value = annual_expense / self.current_budget_constraint
# 15330.806920518813
#  0

# %%
basepolicy1(10000, env_test, 24)
# Out:
# C:\Users\kubaw\AppData\Local\Temp\ipykernel_10116\1914628558.py:213: RuntimeWarning: divide by zero encountered in scalar divide
#   value = annual_expense / self.current_budget_constraint
# 12150.145309023697
#  0
